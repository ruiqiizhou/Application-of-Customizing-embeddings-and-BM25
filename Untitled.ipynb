# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (0.28.0)
# Requirement already satisfied: aiohttp in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from openai) (3.8.5)
# Requirement already satisfied: requests>=2.20 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from openai) (4.65.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/ruiqizhou/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->openai) (4.0.3)

# %%
## imports
from typing import List, Tuple  # for type hints

import numpy as np  # for manipulating arrays
import pandas as pd  # for manipulating data in dataframes
import pickle  # for saving the embeddings cache
import plotly.express as px  # for plots
import random  # for generating run IDs
from sklearn.model_selection import train_test_split  # for splitting train & test data
import torch  # for matrix optimization

from openai.embeddings_utils import get_embedding, cosine_similarity  # for embeddings

# %%
# input parameters
embedding_cache_path = "snli_embedding_cache.pkl"  # embeddings will be saved/loaded here
default_embedding_engine = "babbage-similarity"  # text-embedding-ada-002 is recommended
num_pairs_to_embed = 1000  # 1000 is arbitrary
local_dataset_path = "data/snli_1.0_train_2k.csv"  # download from: https://nlp.stanford.edu/projects/snli/

# %%
def process_input_data(df: pd.DataFrame) -> pd.DataFrame:
    # you can customize this to preprocess your own dataset
    # output should be a dataframe with 3 columns: text_1, text_2, label (1 for similar, -1 for dissimilar)
    df["label"] = df["gold_label"]
    df = df[df["label"].isin(["entailment"])]
    df["label"] = df["label"].apply(lambda x: {"entailment": 1, "contradiction": -1}[x])
    df = df.rename(columns={"sentence1": "text_1", "sentence2": "text_2"})
    df = df[["text_1", "text_2", "label"]]
    df = df.head(num_pairs_to_embed)
    return df

# %%
# sample = pd.read_csv("/Users/ruiqizhou/Downloads/annotation_10.csv")

# %%
sample = pd.read_csv("/Users/ruiqizhou/Downloads/annotation_1.csv", nrows=1000)

# %%
sample
# Out:
#                                        title & content  \
# 0    This 4th of July, Amazon is stacked with deals...
# 1    Investors Spurn Dividend-Paying Stocks as AI B...
# 2    'Haven’t had a speeding ticket in years!' This...
# 3    A flight attendant shares the 10 items she alw...
# 4    Run, don't walk: A podiatrist points us to the...
# ..                                                 ...
# 995  2023 has barely started and Amazon, Salesforce...
# 996  Save up to 49% off cleaning products this Janu...
# 997  AP News Digest 3:20 am - Here are the AP’s lat...
# 998  Amazon to cut 18,000 jobs - live updates - Ama...
# 999  Big Tech job cuts, ADP hiring, Hong Kong borde...
#
#                                              sentiment  \
# 0    {'positive': 0.093311146, 'negative': 0.021053...
# 1    {'positive': 0.12919189, 'negative': 0.7902378...
# 2    {'positive': 0.038932458, 'negative': 0.191211...
# 3    {'positive': 0.09565405, 'negative': 0.0176123...
# 4    {'positive': 0.13780414, 'negative': 0.0154630...
# ..                                                 ...
# 995  {'positive': 0.006924565, 'negative': 0.968069...
# 996  {'positive': 0.024229906, 'negative': 0.814925...
# 997  {'positive': 0.02699591, 'negative': 0.1537630...
# 998  {'positive': 0.009658997, 'negative': 0.971661...
# 999  {'positive': 0.047745593, 'negative': 0.901162...
#
#                                                summary  \
# 0    This 4th of July, Amazon is offering deals on ...
# 1    Shares of companies with chunky dividends were...
# 2    The Uniden DFR1 radar detector is available at...
# 3    A flight attendant Sakkara Barnwell, a former ...
# 4    This is the 4th of July weekend, when Amazon i...
# ..                                                 ...
# 995  \n\n• Amazon will be cutting over 18,000 jobs,...
# 996  Save up to 49% off cleaning products this Janu...
# 997  Eight family members, five of them children, w...
# 998  The majority of job losses will be in in Amazo...
# 999  There are also jobless claims and trade data d...
#
#                                            description Ticker          Sector  \
# 0    You'll wear these flowy maxi dresses 'til the ...   AMZN  Consumer Goods
# 1    The shares have suffered their worst first-hal...   AMZN  Consumer Goods
# 2    If you're feeling fast and furious, this gadge...   AMZN  Consumer Goods
# 3    Yahoo talked to a travel pro to get her clever...   AMZN  Consumer Goods
# 4    These supportive sneakers are just what the do...   AMZN  Consumer Goods
# ..                                                 ...    ...             ...
# 995  The rash of layoffs come after tech companies ...   AMZN  Consumer Goods
# 996  SHOPPING: Get a heads start on sprucing up you...   AMZN  Consumer Goods
# 997  Here are the AP’s latest coverage plans, top s...   AMZN  Consumer Goods
# 998  Amazon will extend its job cutting plans this ...   AMZN  Consumer Goods
# 999                                  By Geoffrey Smith   AMZN  Consumer Goods
#
#        Industry         Company  \
# 0    E-Commerce  Amazon.com Inc
# 1    E-Commerce  Amazon.com Inc
# 2    E-Commerce  Amazon.com Inc
# 3    E-Commerce  Amazon.com Inc
# 4    E-Commerce  Amazon.com Inc
# ..          ...             ...
# 995  E-Commerce  Amazon.com Inc
# 996  E-Commerce  Amazon.com Inc
# 997  E-Commerce  Amazon.com Inc
# 998  E-Commerce  Amazon.com Inc
# 999  E-Commerce  Amazon.com Inc
#
#                                         news_embedding
# 0    [-0.015432381243255985, -0.0034410926217465602...
# 1    [-0.024306956033299715, -0.02670285239435737, ...
# 2    [-0.006583285561824122, 0.006980889960853821, ...
# 3    [0.01807667332348691, 0.006251572691275958, 0....
# 4    [0.015015614536495827, -0.006239550785772387, ...
# ..                                                 ...
# 995  [-0.021191236326306515, -0.040097916151262285,...
# 996  [0.013427899243692174, 0.011660044102867324, -...
# 997  [-0.003439105008929281, 0.010130104979765835, ...
# 998  [-0.01570868787498086, -0.019182098087241917, ...
# 999  [-0.019411060863069637, -0.03473271373114525, ...
#
# [1000 rows x 9 columns]

# %%
topics = pd.read_csv("/Users/ruiqizhou/Downloads/SASB_embeddings.csv")

# %%
topics
# Out:
#                                       Sector  \
# 0                                Health Care
# 1                             Transportation
# 2                             Consumer Goods
# 3                Technology & Communications
# 4                                Health Care
# ..                                       ...
# 62         Extractives & Minerals Processing
# 63                            Infrastructure
# 64                            Infrastructure
# 65                            Consumer Goods
# 66  Renewable Resources & Alternative Energy
#
#                                             Industry  \
# 0                       Medical Equipment & Supplies
# 1                                           Airlines
# 2   Multiline and Specialty Retailers & Distributors
# 3                                           Hardware
# 4                    Biotechnology & Pharmaceuticals
# ..                                               ...
# 62                            Iron & Steel Producers
# 63               Engineering & Construction Services
# 64                                  Waste Management
# 65                           Appliance Manufacturing
# 66                               Forestry Management
#
#                                                  SASB  \
# 0   {'Product Safety': 'Information on product saf...
# 1   {'Competitive Behaviour': 'The Airlines indust...
# 2   {'Workforce Diversity & Inclusion': 'The Multi...
# 3   {'Supply Chain Management': 'Entities in the H...
# 4   {'Employee Recruitment, Development & Retentio...
# ..                                                ...
# 62  {'Greenhouse Gas Emissions': 'Iron and steel p...
# 63  {'Climate Impacts of Business Mix': 'Engineeri...
# 64  {'Greenhouse Gas Emissions': 'Landfills are a ...
# 65  {'Product Safety': 'Product safety is of utmos...
# 66  {'Rights of Indigenous Peoples': 'Forests cont...
#
#                                        SASB_embedding
# 0   {'Product Safety': [0.009879209524762098, -0.0...
# 1   {'Competitive Behaviour': [8.349528820836388e-...
# 2   {'Workforce Diversity & Inclusion': [-0.022194...
# 3   {'Supply Chain Management': [-0.00200234759469...
# 4   {'Employee Recruitment, Development & Retentio...
# ..                                                ...
# 62  {'Greenhouse Gas Emissions': [-0.0024575652239...
# 63  {'Climate Impacts of Business Mix': [0.0138161...
# 64  {'Greenhouse Gas Emissions': [-0.0001698792302...
# 65  {'Product Safety': [0.009562687448008114, -0.0...
# 66  {'Rights of Indigenous Peoples': [0.0056513989...
#
# [67 rows x 4 columns]

# %%
import ast

# Convert the string representation of dictionaries in the 'SASB' column to actual dictionaries
topics['SASB'] = topics['SASB'].apply(ast.literal_eval)

# Check the type of the first element in the 'SASB' column to confirm the conversion
type(topics.loc[0, 'SASB'])
# Out:
# dict

# %%
merged_table = pd.merge(sample, topics, on= ['Sector', 'Industry'])

# %%
merged_table
# Out:
#                                        title & content  \
# 0    This 4th of July, Amazon is stacked with deals...
# 1    Investors Spurn Dividend-Paying Stocks as AI B...
# 2    'Haven’t had a speeding ticket in years!' This...
# 3    A flight attendant shares the 10 items she alw...
# 4    Run, don't walk: A podiatrist points us to the...
# ..                                                 ...
# 995  2023 has barely started and Amazon, Salesforce...
# 996  Save up to 49% off cleaning products this Janu...
# 997  AP News Digest 3:20 am - Here are the AP’s lat...
# 998  Amazon to cut 18,000 jobs - live updates - Ama...
# 999  Big Tech job cuts, ADP hiring, Hong Kong borde...
#
#                                              sentiment  \
# 0    {'positive': 0.093311146, 'negative': 0.021053...
# 1    {'positive': 0.12919189, 'negative': 0.7902378...
# 2    {'positive': 0.038932458, 'negative': 0.191211...
# 3    {'positive': 0.09565405, 'negative': 0.0176123...
# 4    {'positive': 0.13780414, 'negative': 0.0154630...
# ..                                                 ...
# 995  {'positive': 0.006924565, 'negative': 0.968069...
# 996  {'positive': 0.024229906, 'negative': 0.814925...
# 997  {'positive': 0.02699591, 'negative': 0.1537630...
# 998  {'positive': 0.009658997, 'negative': 0.971661...
# 999  {'positive': 0.047745593, 'negative': 0.901162...
#
#                                                summary  \
# 0    This 4th of July, Amazon is offering deals on ...
# 1    Shares of companies with chunky dividends were...
# 2    The Uniden DFR1 radar detector is available at...
# 3    A flight attendant Sakkara Barnwell, a former ...
# 4    This is the 4th of July weekend, when Amazon i...
# ..                                                 ...
# 995  \n\n• Amazon will be cutting over 18,000 jobs,...
# 996  Save up to 49% off cleaning products this Janu...
# 997  Eight family members, five of them children, w...
# 998  The majority of job losses will be in in Amazo...
# 999  There are also jobless claims and trade data d...
#
#                                            description Ticker          Sector  \
# 0    You'll wear these flowy maxi dresses 'til the ...   AMZN  Consumer Goods
# 1    The shares have suffered their worst first-hal...   AMZN  Consumer Goods
# 2    If you're feeling fast and furious, this gadge...   AMZN  Consumer Goods
# 3    Yahoo talked to a travel pro to get her clever...   AMZN  Consumer Goods
# 4    These supportive sneakers are just what the do...   AMZN  Consumer Goods
# ..                                                 ...    ...             ...
# 995  The rash of layoffs come after tech companies ...   AMZN  Consumer Goods
# 996  SHOPPING: Get a heads start on sprucing up you...   AMZN  Consumer Goods
# 997  Here are the AP’s latest coverage plans, top s...   AMZN  Consumer Goods
# 998  Amazon will extend its job cutting plans this ...   AMZN  Consumer Goods
# 999                                  By Geoffrey Smith   AMZN  Consumer Goods
#
#        Industry         Company  \
# 0    E-Commerce  Amazon.com Inc
# 1    E-Commerce  Amazon.com Inc
# 2    E-Commerce  Amazon.com Inc
# 3    E-Commerce  Amazon.com Inc
# 4    E-Commerce  Amazon.com Inc
# ..          ...             ...
# 995  E-Commerce  Amazon.com Inc
# 996  E-Commerce  Amazon.com Inc
# 997  E-Commerce  Amazon.com Inc
# 998  E-Commerce  Amazon.com Inc
# 999  E-Commerce  Amazon.com Inc
#
#                                         news_embedding  \
# 0    [-0.015432381243255985, -0.0034410926217465602...
# 1    [-0.024306956033299715, -0.02670285239435737, ...
# 2    [-0.006583285561824122, 0.006980889960853821, ...
# 3    [0.01807667332348691, 0.006251572691275958, 0....
# 4    [0.015015614536495827, -0.006239550785772387, ...
# ..                                                 ...
# 995  [-0.021191236326306515, -0.040097916151262285,...
# 996  [0.013427899243692174, 0.011660044102867324, -...
# 997  [-0.003439105008929281, 0.010130104979765835, ...
# 998  [-0.01570868787498086, -0.019182098087241917, ...
# 999  [-0.019411060863069637, -0.03473271373114525, ...
#
#                                                   SASB  \
# 0    {'Product Packaging & Distribution': 'A signif...
# 1    {'Product Packaging & Distribution': 'A signif...
# 2    {'Product Packaging & Distribution': 'A signif...
# 3    {'Product Packaging & Distribution': 'A signif...
# 4    {'Product Packaging & Distribution': 'A signif...
# ..                                                 ...
# 995  {'Product Packaging & Distribution': 'A signif...
# 996  {'Product Packaging & Distribution': 'A signif...
# 997  {'Product Packaging & Distribution': 'A signif...
# 998  {'Product Packaging & Distribution': 'A signif...
# 999  {'Product Packaging & Distribution': 'A signif...
#
#                                         SASB_embedding
# 0    {'Product Packaging & Distribution': [0.017690...
# 1    {'Product Packaging & Distribution': [0.017690...
# 2    {'Product Packaging & Distribution': [0.017690...
# 3    {'Product Packaging & Distribution': [0.017690...
# 4    {'Product Packaging & Distribution': [0.017690...
# ..                                                 ...
# 995  {'Product Packaging & Distribution': [0.017690...
# 996  {'Product Packaging & Distribution': [0.017690...
# 997  {'Product Packaging & Distribution': [0.017690...
# 998  {'Product Packaging & Distribution': [0.017690...
# 999  {'Product Packaging & Distribution': [0.017690...
#
# [1000 rows x 11 columns]

# %%
merged_table.loc[0,'SASB_embedding']
# Out:
# "{'Competitive Behaviour': [8.349528820836388e-05, -0.014206097499907923, 0.012499265406737183, -0.030171545304434517, -0.04230318602500391, 0.0027374967541469153, -0.007293426451545461, 0.01769853946908259, -0.024171372941290382, -0.03153701135150014, -0.00407342148189606, 0.04324850824313122, -0.0034661828634507015, 0.004358987335791376, 0.0038370906945335856, -0.006594281661558153, 0.03311254838171234, 0.001106979328423451, 0.010674268036300527, -0.007142437175709266, -0.03534455979539467, 0.004441046633725143, -0.038443118438338864, -0.02696795210123961, -0.0006474474811834694, 0.029672626486630757, 0.015006995800706649, -0.03263988727264868, 0.012912844342829173, 0.01909026508753347, 0.006354668660603168, 0.012729031068422698, -0.007319685557269427, 0.00476928382546021, -0.025536838988356007, -0.009466355692256123, 0.009413837480808191, 0.007096484322768936, 0.022517059059567576, 0.006761682238187555, 0.005629264764891894, 0.01544026941533758, -0.026560938057993935, 0.01838127342393798, -0.004089833248350556, 0.005458581276178047, 0.011061587401007263, -0.0023009413915847598, 0.002051481284190947, -0.004887449102726125, 0.012098816256337819, 0.02465716383604667, -0.022477669702489694, -0.0006035458080116459, 0.003764878503038645, 0.014258615711355855, 0.0025930723711570344, 0.0177773163205932, -0.0027604731806170806, -0.00827157220258177, -0.0025274250725084075, 0.0005469249459883951, -0.027624426484709745, 0.00687984751545347, -0.031248163516842956, 0.006945495046932742, -0.0059804781502664816, 0.006919236406870064, -0.004536235251690249, 0.0018020211767971342, 0.007286861558699147, 0.029121186663411333, 0.03334888079888932, 0.010772738635027502, -0.019667960756847836, -0.025615615839866615, 0.0018414096025524392, -0.001866027368649505, -0.03179960334006238, 0.029672626486630757, 0.022412022636671712, 0.00945979079940981, -0.008855834627387609, 0.0024289537752895008, 0.025510581279615904, -0.002148311125367631, -0.009853675056962859, 0.02337047464049166, -1.2783292766666754e-05, 0.02402694902396179, 0.006400621513543497, 0.00025212706600879716, 0.00579010091433627, 0.01870950875302789, -0.00860637428716315, -0.009466355692256123, -0.01202003940482721, 0.01874889811010577, 0.016635051042366778, -0.011790273743141693, 0.0026324607969123396, 0.01390411987955811, -0.028385937291075743, -0.010149088715788936, -0.019536666625211873, -0.004569059250260529, 0.0061183376404100485, -0.012722466175576385, 0.008186231389547424, -0.03250859314101271, 0.019339725427757925, -0.00942696726650082, -0.00563254721131505, -0.0024043361256077577, 0.016070483296099884, -0.021046556589606087, 0.00966329782103265, 0.011770579064602752, -0.0008665457158626754, -0.002392847795957353, 0.026258960437644124, 0.033060032964232135, 0.014770665246174819, -0.01414045043408994, 0.025392415071027415, 0.0017183207720671114, -0.0012834067491318563, -0.009820851524053868, -0.01631994363632434, -0.024762200258942536, 0.02062641462331294, 0.02497227124208911, 0.015991706444589273, -0.015308974352379039, -0.012322017025177021, -0.0016854970063274756, -0.01828936678673474, 0.02828090086817988, 8.718795312292373e-05, -0.033270102084733556, 0.004099680121958737, 0.011731190638847448, -0.016963288234101846, -0.019129652581966194, -4.3850414050292176e-05, 0.016070483296099884, 0.004260516271403114, 0.005911548638025343, 0.01390411987955811, 0.007601968964741587, 0.007030836791289665, -0.024368316001389487, -0.026258960437644124, 0.020285047645885245, 0.0246702936217393, 0.014967607374951343, -0.00012380689474422406, -0.0009691197800722227, -0.030381618150226247, -0.0344254971486526, -0.006239785364099121, 0.008796751523093362, -0.0002925412271675081, 0.029410036360713675, 0.023961301958143808, 0.014153580219782568, -0.00025766604882872165, 0.0039716679710846406, 0.004818519124823697, -0.008212490029610102, 0.016621923119319305, -0.0016083613780284443, -0.02914744623479659, 0.0010667702910623568, -0.005071261911471311, 0.008586680539946788, -0.009820851524053868, 0.0 ...

# %%
merged_table.loc[0,'news_embedding']
# Out:
# '[-0.013338859064795797, -0.011341818499310643, 0.01203045330552243, -0.009048663924073148, -0.02160936573235543, -0.0020194221093831504, -0.03539583797998243, -0.010398387808972126, 0.012395429305779844, -0.024198632454700136, 0.008277392866610143, 0.022311772936668233, -0.010329524887144486, 0.000880591970319205, 0.016306876979466627, -0.005977351626660858, 0.008862731893096621, -0.03751683199102185, 0.025534584872820665, -0.025933993730975748, -0.019626097564971294, 0.023496225250387335, -0.008972913871872436, 0.006004896888524171, -0.018221281293700563, -0.003394970404874737, 0.019102733398616817, -0.01492960643572049, -0.004310855134858019, 0.002482529007247351, -0.0013256223046375218, -0.008022597913805976, -0.027807080850906638, 0.019598550906124133, -0.03153948083002227, -0.01166547637394245, 0.002425716700927458, -0.013517904896721816, 0.03264129875513529, -0.011796316949869785, -0.008318710060913188, 0.012905019211388176, -0.004878978663718229, 0.006931111149913854, -0.019515914654872915, -0.00507868309279577, 0.018579371094907468, 0.019653642361173323, 0.0016656358333368478, 0.01961232330422515, 0.005836181286496478, 0.019694959555476368, -0.029473576411386912, -0.016086513021914998, 0.022366864391717423, 0.011038818290507794, 0.019915323513027997, 0.011355590897411658, 0.00607720384119963, 0.0061047491030629415, -0.003615333663934442, 0.001495198681546528, -0.02177463823485787, 0.028344215552717, 0.003790935465012642, -0.016141604476964187, -0.0115552953264892, 0.00682781583584983, 0.001296355376596262, -0.007327075977221118, 0.015521832592580042, 0.02239440918791945, 0.023096816392232253, -0.01262956566143249, 0.0008375522949309684, 0.001943672173597759, -0.011451999546763892, 0.0005767318015422877, 0.017422465440035527, 0.014502652781363378, 0.018744643597409908, -0.005288716820449073, -0.04038155412596737, 0.0018128315976704223, 0.002980067831686654, -0.0033502091797238736, 0.011004387295255259, -0.00013772699325657038, -0.029253214316480414, 0.0024377677820964874, 0.02601662998222697, 0.021154867281796292, 0.016830239283175976, 0.016251785524417438, -0.02132013978429873, 0.012870587284813073, -0.009909457431837881, 0.0265262198878353, -0.011073250217082897, -0.05679861401553238, 0.012533157012080255, -0.005423000495901663, -0.021471638026055024, -0.0022156829732741553, -0.026498673228988138, 0.013152927965141835, 0.021292593125451568, 0.0028320112924717657, 0.0055090798466781365, -0.027531627300950948, -0.007196235401293782, -0.03641501779119909, 0.014902060708195896, -0.02798612575151009, -0.001189616963006984, 0.009757957327436458, -0.0017680702561042381, 0.02118241207799832, 0.024666905166005424, -0.021898591680412135, 0.0421995516534942, 0.004748138087790892, 0.015935012917513574, -0.02132013978429873, 0.017243420539432074, 0.0031763289284083003, -0.023055499197929208, -0.005278387056212029, 0.0012343781881578473, -0.006889793024288245, 0.006008339988049424, 0.011830748876444887, -0.0003083793533191335, -0.021981227931663353, 0.0012825826292492853, 0.003420794349806064, -0.009847479777738184, 0.010694500887401901, -0.031181391028815363, -0.006834702034900338, -0.004069832580154867, 0.018455417649353205, -0.010384615410871111, -0.02059018592113877, -0.031071209981362112, 0.007871097809404553, 0.01150020387144001, 0.012305906855478117, 0.016045195827611953, -0.019598550906124133, 0.024033359952197696, -0.02012191320983348, -0.012932564938912771, 0.0015726701670945465, -0.013875994697928724, -0.011837635075495396, 0.003615333663934442, 0.009269026950302213, -0.0047860131138912475, -0.01246429315893005, -0.038205466797233634, -0.024556724118552177, 0.002460148394671919, 0.04321873146471086, -0.005192307705435556, 0.029335850567731633, 0.009255254552201197, -0.015907468121311545, -0.01776678284314142, -0.01983268726177678, -0.009806161652112575, -0.0059876809252366195, -0.027269944286451145, 0.007230667327868884, -0.019791370067473734, 0.03382575106885439, 0.004365945658584643, -0.002596153852717778, -0.05346561 ...

# %%
df = pd.read_excel("/Users/ruiqizhou/Downloads/ANNOTATAION_4_UPDATE.xlsx")

# %%
df
# Out:
#      index                                    title & content  \
# 0    12024  Delays Won‚Äôt Hurt Japan‚Äôs First Casino, Os...
# 1    20675  MetLife (MET) Could Be a Great Choice - Gettin...
# 2    33685  New York Cements Itself as the Gold Mining Cap...
# 3    12072  Shareholders v. Tesla, Nasdaq's diversity rule...
# 4    28164  CFOs Boost Currency Protections, Extend Hedge ...
# ..     ...                                                ...
# 600  21471  ONEOK shares drop on concerns over Magellan pi...
# 601  58375  The Zacks Analyst Blog Atmos Energy, TopBuild,...
# 602   5490  Biden admin works on 'green' natural gas as U....
# 603  23700  Medtronic Executive Vice President and CFO Kar...
# 604  21068  Payments giants see consumer spending 'remarka...
#
#                                              sentiment  \
# 0    {'positive': 0.026093118, 'negative': 0.923414...
# 1    {'positive': 0.8553927, 'negative': 0.01334850...
# 2    {'positive': 0.46477953, 'negative': 0.0338994...
# 3    {'positive': 0.02043453, 'negative': 0.6323841...
# 4    {'positive': 0.031100325, 'negative': 0.955758...
# ..                                                 ...
# 600  {'positive': 0.5536193, 'negative': 0.27749515...
# 601  {'positive': 0.4398147, 'negative': 0.5154524,...
# 602  {'positive': 0.21691072, 'negative': 0.0136983...
# 603  {'positive': 0.1169801, 'negative': 0.01293078...
# 604  {'positive': 0.7621276, 'negative': 0.20106485...
#
#                                                summary  \
# 0    Osaka Governor Hirofumi Yoshimura said that th...
# 1    MetLife (MET) is a Finance stock that has seen...
# 2    This week, top-five producer AngloGold Ashanti...
# 3    \n\nThe case is In re Tesla Inc Securities Lit...
# 4    CFOs Boost Currency Protections, Extend Hedge ...
# ..                                                 ...
# 600  Shares of gas pipeline operator ONEOK Inc fell...
# 601  The Zacks Analyst Blog has highlighted four st...
# 602  The United States is seeking to sustain its li...
# 603  Medtronic Executive Vice President and CFO Kar...
# 604  Quarterly results from credit card giants Mast...
#
#                                            description Ticker  \
# 0    Years of delay to plans for Japan‚Äôs first ca...    MGM
# 1    Dividends are one of the best benefits to bein...    MET
# 2    (Bloomberg) -- The momentum has been building ...    NEM
# 3    Some of the biggest securities cases of 2023 a...   NDAQ
# 4    Coca-Cola, Kimberly-Clark and Prologis are amo...     KO
# ..                                                 ...    ...
# 600  Shares of gas pipeline operator ONEOK Inc fell...    OKE
# 601  Atmos Energy, TopBuild, Axcelis Technologies a...    ATO
# 602  The Biden administration is holding talks with...    WMB
# 603  Medtronic plc (NYSE: MDT), a global leader in ...    MDT
# 604  Credit card major Visa, Mastercard, and Americ...    AXP
#
#                                 Sector                        Industry  \
# 0                             Services                Casinos & Gaming
# 1                           Financials                       Insurance
# 2    Extractives & Minerals Processing                 Metals & Mining
# 3                           Financials  Security & Commodity Exchanges
# 4                      Food & Beverage         Non-Alcoholic Beverages
# ..                                 ...                             ...
# 600  Extractives & Minerals Processing           Oil & Gas - Midstream
# 601                     Infrastructure    Gas Utilities & Distributors
# 602  Extractives & Minerals Processing           Oil & Gas - Midstream
# 603                        Health Care    Medical Equipment & Supplies
# 604                         Financials                Consumer Finance
#
#                         Company  \
# 0     MGM Resorts International
# 1                   Metlife Inc
# 2                  Newmont Corp
# 3                    Nasdaq Inc
# 4                  Coca-Cola Co
# ..                          ...
# 600                   ONEOK Inc
# 601           Atmos Energy Corp
# 602  The Williams Companies Inc
# 603               Medtronic plc
# 604         American Express Co
#
#                                                   SASB  ... GPT's Label ->  \
# 0    {'Internal Controls on Money Laundering': 'By ...  ...            NaN
# 1    {'Financed Emissions': 'Entities participating...  ...            NaN
# 2    {'Tailings Storage Facilities Management': 'Th...  ...            NaN
# 3    {'Managing Conflicts of Interest': 'Security a...  ...            NaN
# 4    {'Water Management': 'Water management relates...  ...            NaN
# ..                                                 ...  ...            ...
# 600  {'Greenhouse Gas Emissions': 'The midstream in...  ...            NaN
# 601  {'Integrity of Gas Delivery Infrastructure': '...  ...            NaN
# 602  {'Greenhouse Gas Emissions': 'The midstream in...  ...            NaN
# 603  {'Product Safety': 'Information on product saf...  ...            NaN
# 604  {'Selling Practices': 'There are three key ele...  ...            NaN
#
#      GPT_ESG_or_not  GPT_firm_or_not GPT_sentiment  \
# 0       Minor focus      Major focus       Neutral
# 1          No focus         No focus       Neutral
# 2       Minor focus      Major focus      Positive
# 3       Major focus      Major focus      Negative
# 4          No focus         No focus       Neutral
# ..              ...              ...           ...
# 600     Minor focus      Minor focus      Negative
# 601     Minor focus      Minor focus      Positive
# 602     Major focus      Minor focus       Neutral
# 603        No focus         No focus       Neutral
# 604     Minor focus      Major focus      Positive
#
#                                             GPT_topics Human Label ->  \
# 0                                   Responsible Gaming            NaN
# 1                                                 None            NaN
# 2    Community Relations, Business Ethics & Transpa...            NaN
# 3    Managing Conflicts of Interest, Promoting Tran...            NaN
# 4                                                 None            NaN
# ..                                                 ...            ...
# 600                        Competitive Behaviour, None            NaN
# 601           Energy Affordability, End-Use Efficiency            NaN
# 602  Greenhouse Gas Emissions, Operational Safety, ...            NaN
# 603                                               None            NaN
# 604  Selling Practices, Customer Privacy, Data Secu...            NaN
#
#       ESG_or_not  firm_or_not sentiment.1  topics
# 0       No focus          NaN         NaN     NaN
# 1       No focus          NaN         NaN     NaN
# 2       No focus          NaN         NaN     NaN
# 3    Major focus  Major focus    Positive     NaN
# 4       No focus          NaN         NaN     NaN
# ..           ...          ...         ...     ...
# 600          NaN          NaN         NaN     NaN
# 601          NaN          NaN         NaN     NaN
# 602          NaN          NaN         NaN     NaN
# 603          NaN          NaN         NaN     NaN
# 604          NaN          NaN         NaN     NaN
#
# [605 rows x 24 columns]

# %%
df['content'] = df['title & content']

# %%
df = df[['content','sentiment','Sector', 'Industry','max_cosine_similarities','ESG_or_not']]

# %%
df
# Out:
#                                                content  \
# 0    Delays Won‚Äôt Hurt Japan‚Äôs First Casino, Os...
# 1    MetLife (MET) Could Be a Great Choice - Gettin...
# 2    New York Cements Itself as the Gold Mining Cap...
# 3    Shareholders v. Tesla, Nasdaq's diversity rule...
# 4    CFOs Boost Currency Protections, Extend Hedge ...
# ..                                                 ...
# 600  ONEOK shares drop on concerns over Magellan pi...
# 601  The Zacks Analyst Blog Atmos Energy, TopBuild,...
# 602  Biden admin works on 'green' natural gas as U....
# 603  Medtronic Executive Vice President and CFO Kar...
# 604  Payments giants see consumer spending 'remarka...
#
#                                              sentiment  \
# 0    {'positive': 0.026093118, 'negative': 0.923414...
# 1    {'positive': 0.8553927, 'negative': 0.01334850...
# 2    {'positive': 0.46477953, 'negative': 0.0338994...
# 3    {'positive': 0.02043453, 'negative': 0.6323841...
# 4    {'positive': 0.031100325, 'negative': 0.955758...
# ..                                                 ...
# 600  {'positive': 0.5536193, 'negative': 0.27749515...
# 601  {'positive': 0.4398147, 'negative': 0.5154524,...
# 602  {'positive': 0.21691072, 'negative': 0.0136983...
# 603  {'positive': 0.1169801, 'negative': 0.01293078...
# 604  {'positive': 0.7621276, 'negative': 0.20106485...
#
#                                 Sector                        Industry  \
# 0                             Services                Casinos & Gaming
# 1                           Financials                       Insurance
# 2    Extractives & Minerals Processing                 Metals & Mining
# 3                           Financials  Security & Commodity Exchanges
# 4                      Food & Beverage         Non-Alcoholic Beverages
# ..                                 ...                             ...
# 600  Extractives & Minerals Processing           Oil & Gas - Midstream
# 601                     Infrastructure    Gas Utilities & Distributors
# 602  Extractives & Minerals Processing           Oil & Gas - Midstream
# 603                        Health Care    Medical Equipment & Supplies
# 604                         Financials                Consumer Finance
#
#      max_cosine_similarities   ESG_or_not
# 0                   0.797453     No focus
# 1                   0.784913     No focus
# 2                   0.771926     No focus
# 3                   0.797389  Major focus
# 4                   0.776955     No focus
# ..                       ...          ...
# 600                 0.783972          NaN
# 601                 0.752961          NaN
# 602                 0.812575          NaN
# 603                 0.781460          NaN
# 604                 0.784474          NaN
#
# [605 rows x 6 columns]

# %%
df = pd.merge(df, topics, on= ['Sector', 'Industry'])

# %%
df
# Out:
#                                                content  \
# 0    Delays Won‚Äôt Hurt Japan‚Äôs First Casino, Os...
# 1    Anti-Casino Rally Held On Eve Of Legislature V...
# 2    Las Vegas Strip Brings Back Superstar Singer -...
# 3    Las Vegas Strip Casinos Accused of Illegally P...
# 4    Blackjack On Broadway: Caesars Palace Casino M...
# ..                                                 ...
# 600  Monday Afternoon Update: 'Digital Fentanyl,' G...
# 601  Live Nation exec will face lawmakers about Tay...
# 602  Live Nation posts 73% jump in revenue and reco...
# 603  Report: DOJ Probes Live Nation After Swift Tic...
# 604  GHOST ADDS SECOND LA DATE ON RE-IMPERATOUR U.S...
#
#                                              sentiment    Sector  \
# 0    {'positive': 0.026093118, 'negative': 0.923414...  Services
# 1    {'positive': 0.036242466, 'negative': 0.826487...  Services
# 2    {'positive': 0.08273419, 'negative': 0.0216881...  Services
# 3    {'positive': 0.018532103, 'negative': 0.873039...  Services
# 4    {'positive': 0.11247342, 'negative': 0.0635238...  Services
# ..                                                 ...       ...
# 600  {'positive': 0.04458833, 'negative': 0.4345133...  Services
# 601  {'positive': 0.0100895455, 'negative': 0.93815...  Services
# 602  {'positive': 0.57705677, 'negative': 0.2456571...  Services
# 603  {'positive': 0.018843884, 'negative': 0.824175...  Services
# 604  {'positive': 0.06888215, 'negative': 0.0213334...  Services
#
#                Industry  max_cosine_similarities   ESG_or_not  \
# 0      Casinos & Gaming                 0.797453     No focus
# 1      Casinos & Gaming                 0.778137  Major focus
# 2      Casinos & Gaming                 0.793890           No
# 3      Casinos & Gaming                 0.787558           No
# 4      Casinos & Gaming                 0.796483           No
# ..                  ...                      ...          ...
# 600  Leisure Facilities                 0.735942           No
# 601  Leisure Facilities                 0.740271        Major
# 602  Leisure Facilities                 0.746974        Minor
# 603  Leisure Facilities                 0.740032     No focus
# 604  Leisure Facilities                 0.735196          NaN
#
#                                                   SASB  \
# 0    {'Internal Controls on Money Laundering': 'By ...
# 1    {'Internal Controls on Money Laundering': 'By ...
# 2    {'Internal Controls on Money Laundering': 'By ...
# 3    {'Internal Controls on Money Laundering': 'By ...
# 4    {'Internal Controls on Money Laundering': 'By ...
# ..                                                 ...
# 600  {'Customer Safety': 'Leisure facility entities...
# 601  {'Customer Safety': 'Leisure facility entities...
# 602  {'Customer Safety': 'Leisure facility entities...
# 603  {'Customer Safety': 'Leisure facility entities...
# 604  {'Customer Safety': 'Leisure facility entities...
#
#                                         SASB_embedding
# 0    {'Internal Controls on Money Laundering': [0.0...
# 1    {'Internal Controls on Money Laundering': [0.0...
# 2    {'Internal Controls on Money Laundering': [0.0...
# 3    {'Internal Controls on Money Laundering': [0.0...
# 4    {'Internal Controls on Money Laundering': [0.0...
# ..                                                 ...
# 600  {'Customer Safety': [0.012655746936361898, -0....
# 601  {'Customer Safety': [0.012655746936361898, -0....
# 602  {'Customer Safety': [0.012655746936361898, -0....
# 603  {'Customer Safety': [0.012655746936361898, -0....
# 604  {'Customer Safety': [0.012655746936361898, -0....
#
# [605 rows x 8 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#                                                content  \
# 0    Delays Won‚Äôt Hurt Japan‚Äôs First Casino, Os...
# 1    Anti-Casino Rally Held On Eve Of Legislature V...
# 2    Las Vegas Strip Brings Back Superstar Singer -...
# 3    Las Vegas Strip Casinos Accused of Illegally P...
# 4    Blackjack On Broadway: Caesars Palace Casino M...
# ..                                                 ...
# 599  Steel Dynamics (STLD) Stock Sinks As Market Ga...
# 600  Monday Afternoon Update: 'Digital Fentanyl,' G...
# 601  Live Nation exec will face lawmakers about Tay...
# 602  Live Nation posts 73% jump in revenue and reco...
# 603  Report: DOJ Probes Live Nation After Swift Tic...
#
#                                              sentiment  \
# 0    {'positive': 0.026093118, 'negative': 0.923414...
# 1    {'positive': 0.036242466, 'negative': 0.826487...
# 2    {'positive': 0.08273419, 'negative': 0.0216881...
# 3    {'positive': 0.018532103, 'negative': 0.873039...
# 4    {'positive': 0.11247342, 'negative': 0.0635238...
# ..                                                 ...
# 599  {'positive': 0.06161075, 'negative': 0.8832018...
# 600  {'positive': 0.04458833, 'negative': 0.4345133...
# 601  {'positive': 0.0100895455, 'negative': 0.93815...
# 602  {'positive': 0.57705677, 'negative': 0.2456571...
# 603  {'positive': 0.018843884, 'negative': 0.824175...
#
#                                 Sector                Industry  \
# 0                             Services        Casinos & Gaming
# 1                             Services        Casinos & Gaming
# 2                             Services        Casinos & Gaming
# 3                             Services        Casinos & Gaming
# 4                             Services        Casinos & Gaming
# ..                                 ...                     ...
# 599  Extractives & Minerals Processing  Iron & Steel Producers
# 600                           Services      Leisure Facilities
# 601                           Services      Leisure Facilities
# 602                           Services      Leisure Facilities
# 603                           Services      Leisure Facilities
#
#      max_cosine_similarities   ESG_or_not  \
# 0                   0.797453     No focus
# 1                   0.778137  Major focus
# 2                   0.793890           No
# 3                   0.787558           No
# 4                   0.796483           No
# ..                       ...          ...
# 599                 0.752282     No focus
# 600                 0.735942           No
# 601                 0.740271        Major
# 602                 0.746974        Minor
# 603                 0.740032     No focus
#
#                                                   SASB  \
# 0    {'Internal Controls on Money Laundering': 'By ...
# 1    {'Internal Controls on Money Laundering': 'By ...
# 2    {'Internal Controls on Money Laundering': 'By ...
# 3    {'Internal Controls on Money Laundering': 'By ...
# 4    {'Internal Controls on Money Laundering': 'By ...
# ..                                                 ...
# 599  {'Greenhouse Gas Emissions': 'Iron and steel p...
# 600  {'Customer Safety': 'Leisure facility entities...
# 601  {'Customer Safety': 'Leisure facility entities...
# 602  {'Customer Safety': 'Leisure facility entities...
# 603  {'Customer Safety': 'Leisure facility entities...
#
#                                         SASB_embedding
# 0    {'Internal Controls on Money Laundering': [0.0...
# 1    {'Internal Controls on Money Laundering': [0.0...
# 2    {'Internal Controls on Money Laundering': [0.0...
# 3    {'Internal Controls on Money Laundering': [0.0...
# 4    {'Internal Controls on Money Laundering': [0.0...
# ..                                                 ...
# 599  {'Greenhouse Gas Emissions': [-0.0024575652239...
# 600  {'Customer Safety': [0.012655746936361898, -0....
# 601  {'Customer Safety': [0.012655746936361898, -0....
# 602  {'Customer Safety': [0.012655746936361898, -0....
# 603  {'Customer Safety': [0.012655746936361898, -0....
#
# [555 rows x 8 columns]

# %%
# split data into train and test sets
test_fraction = 0.5  # 0.5 is fairly arbitrary
random_seed = 123  # random seed is arbitrary, but is helpful in reproducibility
train_df, test_df = train_test_split(
    df, test_size=test_fraction, random_state=random_seed
)
train_df.loc[:, "dataset"] = "train"
test_df.loc[:, "dataset"] = "test"

# %%
df = pd.concat([train_df, test_df])

# %%
df
# Out:
#                                                content  \
# 87   More millennials are turning 40 ‚Äî and they'r...
# 53   FedEx Parks Planes, Maersk Cancels Sails: Worl...
# 301  You could be buying shoplifted stuff on Amazon...
# 184  Marketers: Turn Impressions Into Intent This H...
# 419  Royal Caribbean Inks Sustainable Shipbuilding ...
# ..                                                 ...
# 521  Waste Management (WM) Stock Moves -0.91%: What...
# 19   Newmont Corporation (NEM) Stock Moves -0.58%: ...
# 29   CFOs Boost Currency Protections, Extend Hedge ...
# 578  5,000 GM Employees Reportedly Take Buyouts In ...
# 74   Dexcom to build its first European factory in ...
#
#                                              sentiment  \
# 87   {'positive': 0.06741135, 'negative': 0.1715823...
# 53   {'positive': 0.0276921, 'negative': 0.91408736...
# 301  {'positive': 0.034610316, 'negative': 0.476638...
# 184  {'positive': 0.09345539, 'negative': 0.0399913...
# 419  {'positive': 0.30869853, 'negative': 0.0087451...
# ..                                                 ...
# 521  {'positive': 0.6840206, 'negative': 0.23210213...
# 19   {'positive': 0.07588659, 'negative': 0.8466317...
# 29   {'positive': 0.031100325, 'negative': 0.955758...
# 578  {'positive': 0.013290622, 'negative': 0.963200...
# 74   {'positive': 0.8870371, 'negative': 0.06326054...
#
#                                 Sector  \
# 87                            Services
# 53                      Transportation
# 301                     Consumer Goods
# 184                     Consumer Goods
# 419                     Transportation
# ..                                 ...
# 521                     Infrastructure
# 19   Extractives & Minerals Processing
# 29                     Food & Beverage
# 578                     Transportation
# 74                         Health Care
#
#                                              Industry  \
# 87                                   Hotels & Lodging
# 53                            Air Freight & Logistics
# 301  Multiline and Specialty Retailers & Distributors
# 184                                        E-Commerce
# 419                                      Cruise Lines
# ..                                                ...
# 521                                  Waste Management
# 19                                    Metals & Mining
# 29                            Non-Alcoholic Beverages
# 578                                       Automobiles
# 74                       Medical Equipment & Supplies
#
#      max_cosine_similarities   ESG_or_not  \
# 87                  0.785040     No focus
# 53                  0.806254  Minor focus
# 301                 0.803166  Major focus
# 184                 0.802793        Minor
# 419                 0.792948        Major
# ..                       ...          ...
# 521                 0.805994           No
# 19                  0.756432           No
# 29                  0.776955     No focus
# 578                 0.811529  Major focus
# 74                  0.764248        Major
#
#                                                   SASB  \
# 87   {'Water Management': 'Hotel buildings require ...
# 53   {'Greenhouse Gas Emissions': 'Air Freight & Lo...
# 301  {'Workforce Diversity & Inclusion': 'The Multi...
# 184  {'Product Packaging & Distribution': 'A signif...
# 419  {'Customer Health & Safety': 'Cruise lines off...
# ..                                                 ...
# 521  {'Greenhouse Gas Emissions': 'Landfills are a ...
# 19   {'Tailings Storage Facilities Management': 'Th...
# 29   {'Water Management': 'Water management relates...
# 578  {'Product Safety': 'Driving is a risky activit...
# 74   {'Product Safety': 'Information on product saf...
#
#                                         SASB_embedding dataset
# 87   {'Water Management': [0.013346040463976059, -0...   train
# 53   {'Greenhouse Gas Emissions': [0.00950879266272...   train
# 301  {'Workforce Diversity & Inclusion': [-0.022194...   train
# 184  {'Product Packaging & Distribution': [0.017690...   train
# 419  {'Customer Health & Safety': [0.02446571152799...   train
# ..                                                 ...     ...
# 521  {'Greenhouse Gas Emissions': [-0.0001698792302...    test
# 19   {'Tailings Storage Facilities Management': [0....    test
# 29   {'Water Management': [0.007515041336335117, -0...    test
# 578  {'Product Safety': [-0.00859951505673047, -0.0...    test
# 74   {'Product Safety': [0.009879209524762098, -0.0...    test
#
# [555 rows x 9 columns]

# %%
# check that training and test sets are balanced
px.histogram(
    df,
    x="max_cosine_similarities",
    color="ESG_or_not",
    barmode="overlay",
    width=500,
    facet_row="dataset",
).show()
# Out:
# <div>                            <div id="95dcfc2b-9466-4d38-8fb5-ccc05e844d02" class="plotly-graph-div" style="height:525px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95dcfc2b-9466-4d38-8fb5-ccc05e844d02")) {                    Plotly.newPlot(                        "95dcfc2b-9466-4d38-8fb5-ccc05e844d02",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ESG_or_not=No focus<br>dataset=train<br>max_cosine_similarities=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No focus","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"No focus","offsetgroup":"No focus","orientation":"v","showlegend":true,"x":[0.7850402820485012,0.8049818404820539,0.7904866177327732,0.7913441256791393,0.8001530534027864,0.7400315108747434,0.7708177671199655,0.7671875167426077,0.7978195877036646,0.775894086639331,0.7700265822766114,0.7706900505956911,0.7707239191238695,0.7470656011995619,0.7936121619042715,0.7958630187108462,0.7669122190675424,0.7910461040049697,0.7576652768953196,0.7703167269762533,0.77934984805944,0.8068059107503323,0.7835096920917896,0.7452246563427205,0.7609414601184487,0.7789736127753467,0.7870878140286368,0.76908467642113,0.8089632271248055,0.7987271683229803,0.8065113279281491,0.8068500971932913,0.7830670139456392,0.7884591529278577,0.7773772246731531,0.7468765443596995,0.775330594752911,0.7852111778687914,0.8106825764779744,0.7899704177405701,0.7639334030037972,0.8018172291074303,0.8034154207310928,0.785512628048305,0.792590750045016,0.7733110931680202,0.8033200131718778,0.771926478318217,0.7758228556331986],"xaxis":"x2","yaxis":"y2","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ESG_or_not=No focus<br>dataset=test<br>max_cosine_similarities=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No focus","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"No focus","offsetgroup":"No focus","orientation":"v","showlegend":false,"x":[0.8109639726932839,0.752281523634492,0.7930584251837134,0.784703104728704,0.7913990034212011,0.7998099497289564,0.7828478921312093,0.7543928705916351,0.7844127043046559,0.7775689712381686,0.799271768315444,0.8084789967849386,0.7717379248464121,0.7404064841521233,0.75441852441763,0.7839138867226711,0.7880121358429348,0.7416261906678275,0.7779733341425662,0.7834136641037759,0.7487107719382652,0.8017311908961395,0.795836597605739,0.7703588382339205,0.7846740239179889,0.7952550679057302,0.784215196222245,0.8125020619123803,0.7521833218751764,0.7974531080090717,0.7234499158966764,0.8096933056106456,0.7742826795188654,0.7930149907409917,0.7604406300820323,0.7860026548873443,0.8062442003236502,0.8054038815707094,0.771364086944262,0.808970364917213,0.7666871475878285,0.8012996944788233,0.8005173246585693,0.7849129982509028,0.7429757665868565,0.7704773564851377,0.7921825052709767,0.7950812140771919,0.7908927658254569,0.7799117942203728,0.7989815809003403,0.7769551882340399],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ESG_or_not=Minor focus<br>dataset=train<br>max_cosine_similarities=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Minor focus","marker":{"color":"#EF553B","opacity":0.5,"pattern":{"shape":""}},"name":"Minor focus","offsetgroup":"Minor focus","orientation":"v","showlegend":true,"x":[0.8062541056120236,0.789953689568706,0.7470920378027941,0.7764834459146555,0.7980731734627678,0.768331469092703,0.8041090121170441,0.7911692161421473,0.7978687944925276,0.7444822186236822,0.8105784451130292,0.7734644970469923,0.8121090574357468,0.7955487333749632,0.7688211366602461],"xaxis":"x2","yaxis":"y2","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ESG_or_not=Minor focus<br>dataset=test<br>max_cosine_similarities=%{x}<br>count=%{y ...

# %%
def replace_values(x):
    if 'no' in x.lower():
        return 'No'
    else:
        return 'Focus'
    return x

df['ESG_or_not'] = df['ESG_or_not'].apply(replace_values)

# %%
df
# Out:
#                                                content  \
# 87   More millennials are turning 40 ‚Äî and they'r...
# 53   FedEx Parks Planes, Maersk Cancels Sails: Worl...
# 301  You could be buying shoplifted stuff on Amazon...
# 184  Marketers: Turn Impressions Into Intent This H...
# 419  Royal Caribbean Inks Sustainable Shipbuilding ...
# ..                                                 ...
# 521  Waste Management (WM) Stock Moves -0.91%: What...
# 19   Newmont Corporation (NEM) Stock Moves -0.58%: ...
# 29   CFOs Boost Currency Protections, Extend Hedge ...
# 578  5,000 GM Employees Reportedly Take Buyouts In ...
# 74   Dexcom to build its first European factory in ...
#
#                                              sentiment  \
# 87   {'positive': 0.06741135, 'negative': 0.1715823...
# 53   {'positive': 0.0276921, 'negative': 0.91408736...
# 301  {'positive': 0.034610316, 'negative': 0.476638...
# 184  {'positive': 0.09345539, 'negative': 0.0399913...
# 419  {'positive': 0.30869853, 'negative': 0.0087451...
# ..                                                 ...
# 521  {'positive': 0.6840206, 'negative': 0.23210213...
# 19   {'positive': 0.07588659, 'negative': 0.8466317...
# 29   {'positive': 0.031100325, 'negative': 0.955758...
# 578  {'positive': 0.013290622, 'negative': 0.963200...
# 74   {'positive': 0.8870371, 'negative': 0.06326054...
#
#                                 Sector  \
# 87                            Services
# 53                      Transportation
# 301                     Consumer Goods
# 184                     Consumer Goods
# 419                     Transportation
# ..                                 ...
# 521                     Infrastructure
# 19   Extractives & Minerals Processing
# 29                     Food & Beverage
# 578                     Transportation
# 74                         Health Care
#
#                                              Industry  \
# 87                                   Hotels & Lodging
# 53                            Air Freight & Logistics
# 301  Multiline and Specialty Retailers & Distributors
# 184                                        E-Commerce
# 419                                      Cruise Lines
# ..                                                ...
# 521                                  Waste Management
# 19                                    Metals & Mining
# 29                            Non-Alcoholic Beverages
# 578                                       Automobiles
# 74                       Medical Equipment & Supplies
#
#      max_cosine_similarities ESG_or_not  \
# 87                  0.785040         No
# 53                  0.806254         No
# 301                 0.803166      Focus
# 184                 0.802793         No
# 419                 0.792948      Focus
# ..                       ...        ...
# 521                 0.805994         No
# 19                  0.756432         No
# 29                  0.776955         No
# 578                 0.811529      Focus
# 74                  0.764248      Focus
#
#                                                   SASB  \
# 87   {'Water Management': 'Hotel buildings require ...
# 53   {'Greenhouse Gas Emissions': 'Air Freight & Lo...
# 301  {'Workforce Diversity & Inclusion': 'The Multi...
# 184  {'Product Packaging & Distribution': 'A signif...
# 419  {'Customer Health & Safety': 'Cruise lines off...
# ..                                                 ...
# 521  {'Greenhouse Gas Emissions': 'Landfills are a ...
# 19   {'Tailings Storage Facilities Management': 'Th...
# 29   {'Water Management': 'Water management relates...
# 578  {'Product Safety': 'Driving is a risky activit...
# 74   {'Product Safety': 'Information on product saf...
#
#                                         SASB_embedding dataset
# 87   {'Water Management': [0.013346040463976059, -0...   train
# 53   {'Greenhouse Gas Emissions': [0.00950879266272...   train
# 301  {'Workforce Diversity & Inclusion': [-0.022194...   train
# 184  {'Product Packaging & Distribution': [0.017690...   train
# 419  {'Customer Health & Safety': [0.02446571152799...   train
# ..                                                 ...     ...
# 521  {'Greenhouse Gas Emissions': [-0.0001698792302...    test
# 19   {'Tailings Storage Facilities Management': [0....    test
# 29   {'Water Management': [0.007515041336335117, -0...    test
# 578  {'Product Safety': [-0.00859951505673047, -0.0...    test
# 74   {'Product Safety': [0.009879209524762098, -0.0...    test
#
# [555 rows x 9 columns]

# %%
px.histogram(
    df,
    x="max_cosine_similarities",
    color="ESG_or_not",
    #barmode="overlay",
    width=500,
    facet_row="dataset",
).show()
# Out:
# <div>                            <div id="68d2e320-bb94-4317-bbf5-fe7c4f65c433" class="plotly-graph-div" style="height:525px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68d2e320-bb94-4317-bbf5-fe7c4f65c433")) {                    Plotly.newPlot(                        "68d2e320-bb94-4317-bbf5-fe7c4f65c433",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ESG_or_not=No<br>dataset=train<br>max_cosine_similarities=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"x":[0.7850402820485012,0.8062541056120236,0.8027926382222821,0.7964830262906739,0.8049818404820539,0.7799646804475959,0.789953689568706,0.7779513841826029,0.7913271520388119,0.7829814069398335,0.7904866177327732,0.7913441256791393,0.7736669263181637,0.8093818831616426,0.8108469508778215,0.7714021626812181,0.8120973491563545,0.7679059320581293,0.7713358951453437,0.784977981806507,0.7998373946752388,0.7384050478960354,0.8085581344920496,0.8127212288017498,0.7790144195074336,0.8001530534027864,0.7944241045884564,0.8090815911965477,0.770442574751059,0.7915777467175595,0.7400315108747434,0.7850514251828795,0.7703364193710777,0.7708177671199655,0.8113128708520558,0.801416262063299,0.8099568397911991,0.7470920378027941,0.7671875167426077,0.7978195877036646,0.775894086639331,0.799069179416566,0.7508263423463167,0.7700265822766114,0.7764834459146555,0.8036797715870316,0.7840756231459152,0.8101734121015784,0.7706900505956911,0.7707239191238695,0.8080462251169658,0.8015127731046872,0.787245047872796,0.7980731734627678,0.7470656011995619,0.788291219843394,0.8003240249467356,0.768331469092703,0.8090774345507057,0.8075450948964833,0.7936121619042715,0.7721058069153341,0.7566150535138748,0.7722774712006133,0.7958630187108462,0.7669122190675424,0.7910461040049697,0.7751575846090409,0.7576652768953196,0.7559456629166176,0.7703167269762533,0.7768524735079837,0.77934984805944,0.8068059107503323,0.7914281893628128,0.8015638388331363,0.7970250569733217,0.7467822270233638,0.8027280240918568,0.806329924420983,0.804499408854577,0.7742927185385212,0.773639388509421,0.8041090121170441,0.7835096920917896,0.794922530709874,0.7861985064815517,0.7963867324814621,0.803470996933932,0.7452246563427205,0.8111955801855906,0.7822917573215891,0.7609414601184487,0.7714677144008805,0.7942597422879117,0.7848715075184225,0.7552570605945994,0.7827076298050613,0.7789736127753467,0.7870878140286368,0.76908467642113,0.8062272120224309,0.7432934301382527,0.8064790807954233,0.8089632271248055,0.7987271683229803,0.7707747977541697,0.7956406780618325,0.8084105533004416,0.790455751134923,0.776094563810996,0.8065113279281491,0.8070647635571149,0.8068500971932913,0.7911692161421473,0.7830670139456392,0.7978687944925276,0.7884591529278577,0.7875582786253015,0.7773772246731531,0.7893745652797024,0.7468765443596995,0.7942799896065815,0.7955989946247942,0.7611280875342469,0.7458472212903254,0.7444822186236822,0.775330594752911,0.7852111778687914,0.811296874975259,0.8105784451130292,0.7934489705550045,0.7873185360225432,0.8106825764779744,0.7899704177405701,0.7837238579272912,0.7563797279779486,0.7469739162488072,0.7734644970469923,0.7639334030037972,0.8018172291074303,0.773557470207715,0.7860134981240222,0.7994447403033427,0.8089639579518548,0.7743288712132611,0.8121090574357468,0.7723141875847263,0.7921977220303148,0.7952057052288056,0.8034154207310928,0.7955487333749632,0.7734646770674092,0.785512628048305,0.8101425960832801,0.7961511578233974,0.7359415034303053,0.7771458169997035,0.7938901665824986,0.792590750045016,0.8008264332714595,0.7779503932750913,0.7929247858125921,0.7901181773159683,0.7733110931680202,0.8057451039669177,0.7684838523973728,0.8033200131718778,0.768821 ...

# %%
# calculate accuracy (and its standard error) of predicting label=1 if similarity>x
# x is optimized by sweeping from -1 to 1 in steps of 0.01
def accuracy_and_se(cosine_similarity: float, labeled_similarity: int) -> Tuple[float]:
    accuracies = []
    for threshold_thousandths in range(-1000, 1000, 1):
        threshold = threshold_thousandths / 1000
        total = 0
        correct = 0
        for cs, ls in zip(cosine_similarity, labeled_similarity):
            total += 1
            if cs > threshold:
                prediction = 1
            else:
                prediction = -1
            if prediction == ls:
                correct += 1
        accuracy = correct / total
        accuracies.append(accuracy)
    a = max(accuracies)
    n = len(cosine_similarity)
    standard_error = (a * (1 - a) / n) ** 0.5  # standard error of binomial
    return a, standard_error

# %%
df['ESG_or_not'] = df['ESG_or_not'].map({'Focus': 1, 'No': -1})

# %%
df
# Out:
#                                                content  \
# 87   More millennials are turning 40 ‚Äî and they'r...
# 53   FedEx Parks Planes, Maersk Cancels Sails: Worl...
# 301  You could be buying shoplifted stuff on Amazon...
# 184  Marketers: Turn Impressions Into Intent This H...
# 419  Royal Caribbean Inks Sustainable Shipbuilding ...
# ..                                                 ...
# 521  Waste Management (WM) Stock Moves -0.91%: What...
# 19   Newmont Corporation (NEM) Stock Moves -0.58%: ...
# 29   CFOs Boost Currency Protections, Extend Hedge ...
# 578  5,000 GM Employees Reportedly Take Buyouts In ...
# 74   Dexcom to build its first European factory in ...
#
#                                              sentiment  \
# 87   {'positive': 0.06741135, 'negative': 0.1715823...
# 53   {'positive': 0.0276921, 'negative': 0.91408736...
# 301  {'positive': 0.034610316, 'negative': 0.476638...
# 184  {'positive': 0.09345539, 'negative': 0.0399913...
# 419  {'positive': 0.30869853, 'negative': 0.0087451...
# ..                                                 ...
# 521  {'positive': 0.6840206, 'negative': 0.23210213...
# 19   {'positive': 0.07588659, 'negative': 0.8466317...
# 29   {'positive': 0.031100325, 'negative': 0.955758...
# 578  {'positive': 0.013290622, 'negative': 0.963200...
# 74   {'positive': 0.8870371, 'negative': 0.06326054...
#
#                                 Sector  \
# 87                            Services
# 53                      Transportation
# 301                     Consumer Goods
# 184                     Consumer Goods
# 419                     Transportation
# ..                                 ...
# 521                     Infrastructure
# 19   Extractives & Minerals Processing
# 29                     Food & Beverage
# 578                     Transportation
# 74                         Health Care
#
#                                              Industry  \
# 87                                   Hotels & Lodging
# 53                            Air Freight & Logistics
# 301  Multiline and Specialty Retailers & Distributors
# 184                                        E-Commerce
# 419                                      Cruise Lines
# ..                                                ...
# 521                                  Waste Management
# 19                                    Metals & Mining
# 29                            Non-Alcoholic Beverages
# 578                                       Automobiles
# 74                       Medical Equipment & Supplies
#
#      max_cosine_similarities  ESG_or_not  \
# 87                  0.785040          -1
# 53                  0.806254          -1
# 301                 0.803166           1
# 184                 0.802793          -1
# 419                 0.792948           1
# ..                       ...         ...
# 521                 0.805994          -1
# 19                  0.756432          -1
# 29                  0.776955          -1
# 578                 0.811529           1
# 74                  0.764248           1
#
#                                                   SASB  \
# 87   {'Water Management': 'Hotel buildings require ...
# 53   {'Greenhouse Gas Emissions': 'Air Freight & Lo...
# 301  {'Workforce Diversity & Inclusion': 'The Multi...
# 184  {'Product Packaging & Distribution': 'A signif...
# 419  {'Customer Health & Safety': 'Cruise lines off...
# ..                                                 ...
# 521  {'Greenhouse Gas Emissions': 'Landfills are a ...
# 19   {'Tailings Storage Facilities Management': 'Th...
# 29   {'Water Management': 'Water management relates...
# 578  {'Product Safety': 'Driving is a risky activit...
# 74   {'Product Safety': 'Information on product saf...
#
#                                         SASB_embedding dataset
# 87   {'Water Management': [0.013346040463976059, -0...   train
# 53   {'Greenhouse Gas Emissions': [0.00950879266272...   train
# 301  {'Workforce Diversity & Inclusion': [-0.022194...   train
# 184  {'Product Packaging & Distribution': [0.017690...   train
# 419  {'Customer Health & Safety': [0.02446571152799...   train
# ..                                                 ...     ...
# 521  {'Greenhouse Gas Emissions': [-0.0001698792302...    test
# 19   {'Tailings Storage Facilities Management': [0....    test
# 29   {'Water Management': [0.007515041336335117, -0...    test
# 578  {'Product Safety': [-0.00859951505673047, -0.0...    test
# 74   {'Product Safety': [0.009879209524762098, -0.0...    test
#
# [555 rows x 9 columns]

# %%
for dataset in ["train", "test"]:
    data = df[df["dataset"] == dataset]
    a, se = accuracy_and_se(data["max_cosine_similarities"], data["ESG_or_not"])
    print(f"{dataset} accuracy: {a:0.1%} ± {1.96 * se:0.1%}")
# Out:
# train accuracy: 64.3% ± 5.6%
# test accuracy: 65.5% ± 5.6%

# %%
import openai
openai.api_key = "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"

# %%
news_texts = df['content'].tolist()

# %%
embeddings = openai.Embedding.create(
    input=news_texts,
    engine="text-embedding-ada-002"
)

# %%
Embeddings = [item['embedding'] for item in embeddings['data']]

df['embedding'] = Embeddings

# %%
df
# Out:
#                                                content  \
# 87   More millennials are turning 40 ‚Äî and they'r...
# 53   FedEx Parks Planes, Maersk Cancels Sails: Worl...
# 301  You could be buying shoplifted stuff on Amazon...
# 184  Marketers: Turn Impressions Into Intent This H...
# 419  Royal Caribbean Inks Sustainable Shipbuilding ...
# ..                                                 ...
# 521  Waste Management (WM) Stock Moves -0.91%: What...
# 19   Newmont Corporation (NEM) Stock Moves -0.58%: ...
# 29   CFOs Boost Currency Protections, Extend Hedge ...
# 578  5,000 GM Employees Reportedly Take Buyouts In ...
# 74   Dexcom to build its first European factory in ...
#
#                                              sentiment  \
# 87   {'positive': 0.06741135, 'negative': 0.1715823...
# 53   {'positive': 0.0276921, 'negative': 0.91408736...
# 301  {'positive': 0.034610316, 'negative': 0.476638...
# 184  {'positive': 0.09345539, 'negative': 0.0399913...
# 419  {'positive': 0.30869853, 'negative': 0.0087451...
# ..                                                 ...
# 521  {'positive': 0.6840206, 'negative': 0.23210213...
# 19   {'positive': 0.07588659, 'negative': 0.8466317...
# 29   {'positive': 0.031100325, 'negative': 0.955758...
# 578  {'positive': 0.013290622, 'negative': 0.963200...
# 74   {'positive': 0.8870371, 'negative': 0.06326054...
#
#                                 Sector  \
# 87                            Services
# 53                      Transportation
# 301                     Consumer Goods
# 184                     Consumer Goods
# 419                     Transportation
# ..                                 ...
# 521                     Infrastructure
# 19   Extractives & Minerals Processing
# 29                     Food & Beverage
# 578                     Transportation
# 74                         Health Care
#
#                                              Industry  \
# 87                                   Hotels & Lodging
# 53                            Air Freight & Logistics
# 301  Multiline and Specialty Retailers & Distributors
# 184                                        E-Commerce
# 419                                      Cruise Lines
# ..                                                ...
# 521                                  Waste Management
# 19                                    Metals & Mining
# 29                            Non-Alcoholic Beverages
# 578                                       Automobiles
# 74                       Medical Equipment & Supplies
#
#      max_cosine_similarities  ESG_or_not  \
# 87                  0.785040          -1
# 53                  0.806254          -1
# 301                 0.803166           1
# 184                 0.802793          -1
# 419                 0.792948           1
# ..                       ...         ...
# 521                 0.805994          -1
# 19                  0.756432          -1
# 29                  0.776955          -1
# 578                 0.811529           1
# 74                  0.764248           1
#
#                                                   SASB  \
# 87   {'Water Management': 'Hotel buildings require ...
# 53   {'Greenhouse Gas Emissions': 'Air Freight & Lo...
# 301  {'Workforce Diversity & Inclusion': 'The Multi...
# 184  {'Product Packaging & Distribution': 'A signif...
# 419  {'Customer Health & Safety': 'Cruise lines off...
# ..                                                 ...
# 521  {'Greenhouse Gas Emissions': 'Landfills are a ...
# 19   {'Tailings Storage Facilities Management': 'Th...
# 29   {'Water Management': 'Water management relates...
# 578  {'Product Safety': 'Driving is a risky activit...
# 74   {'Product Safety': 'Information on product saf...
#
#                                         SASB_embedding dataset  \
# 87   {'Water Management': [0.013346040463976059, -0...   train
# 53   {'Greenhouse Gas Emissions': [0.00950879266272...   train
# 301  {'Workforce Diversity & Inclusion': [-0.022194...   train
# 184  {'Product Packaging & Distribution': [0.017690...   train
# 419  {'Customer Health & Safety': [0.02446571152799...   train
# ..                                                 ...     ...
# 521  {'Greenhouse Gas Emissions': [-0.0001698792302...    test
# 19   {'Tailings Storage Facilities Management': [0....    test
# 29   {'Water Management': [0.007515041336335117, -0...    test
# 578  {'Product Safety': [-0.00859951505673047, -0.0...    test
# 74   {'Product Safety': [0.009879209524762098, -0.0...    test
#
#                                              embedding
# 87   [0.0034837801940739155, -0.018379943445324898,...
# 53   [-0.016028370708227158, -0.038418304175138474,...
# 301  [0.006538767833262682, -0.0335729718208313, -0...
# 184  [-0.012135321274399757, -0.015672283247113228,...
# 419  [0.00059090880677104, -0.040115032345056534, 0...
# ..                                                 ...
# 521  [-0.005872064735740423, -0.031545888632535934,...
# 19   [-0.013726205565035343, -0.023092789575457573,...
# 29   [-0.008213700726628304, -0.018072837963700294,...
# 578  [-0.02998894639313221, -0.019518667832016945, ...
# 74   [-0.004129682667553425, -0.011016884818673134,...
#
# [555 rows x 10 columns]

# %%
import ast

def compute_similarity(news_embedding, sasb_string):
    sasb_dict = ast.literal_eval(sasb_string)
    similarities = {}
    for key, sasb_embedding in sasb_dict.items():
        sim = cosine_similarity(news_embedding, sasb_embedding)
        similarities[key] = sim
    return similarities

# %%
df['cosine_similarities'] = df.apply(lambda row: compute_similarity(row['embedding'], row['SASB_embedding']), axis=1)

# %%
df
# Out:
#                                                content  \
# 87   More millennials are turning 40 ‚Äî and they'r...
# 53   FedEx Parks Planes, Maersk Cancels Sails: Worl...
# 301  You could be buying shoplifted stuff on Amazon...
# 184  Marketers: Turn Impressions Into Intent This H...
# 419  Royal Caribbean Inks Sustainable Shipbuilding ...
# ..                                                 ...
# 521  Waste Management (WM) Stock Moves -0.91%: What...
# 19   Newmont Corporation (NEM) Stock Moves -0.58%: ...
# 29   CFOs Boost Currency Protections, Extend Hedge ...
# 578  5,000 GM Employees Reportedly Take Buyouts In ...
# 74   Dexcom to build its first European factory in ...
#
#                                              sentiment  \
# 87   {'positive': 0.06741135, 'negative': 0.1715823...
# 53   {'positive': 0.0276921, 'negative': 0.91408736...
# 301  {'positive': 0.034610316, 'negative': 0.476638...
# 184  {'positive': 0.09345539, 'negative': 0.0399913...
# 419  {'positive': 0.30869853, 'negative': 0.0087451...
# ..                                                 ...
# 521  {'positive': 0.6840206, 'negative': 0.23210213...
# 19   {'positive': 0.07588659, 'negative': 0.8466317...
# 29   {'positive': 0.031100325, 'negative': 0.955758...
# 578  {'positive': 0.013290622, 'negative': 0.963200...
# 74   {'positive': 0.8870371, 'negative': 0.06326054...
#
#                                 Sector  \
# 87                            Services
# 53                      Transportation
# 301                     Consumer Goods
# 184                     Consumer Goods
# 419                     Transportation
# ..                                 ...
# 521                     Infrastructure
# 19   Extractives & Minerals Processing
# 29                     Food & Beverage
# 578                     Transportation
# 74                         Health Care
#
#                                              Industry  \
# 87                                   Hotels & Lodging
# 53                            Air Freight & Logistics
# 301  Multiline and Specialty Retailers & Distributors
# 184                                        E-Commerce
# 419                                      Cruise Lines
# ..                                                ...
# 521                                  Waste Management
# 19                                    Metals & Mining
# 29                            Non-Alcoholic Beverages
# 578                                       Automobiles
# 74                       Medical Equipment & Supplies
#
#      max_cosine_similarities  ESG_or_not  \
# 87                  0.785040          -1
# 53                  0.806254          -1
# 301                 0.803166           1
# 184                 0.802793          -1
# 419                 0.792948           1
# ..                       ...         ...
# 521                 0.805994          -1
# 19                  0.756432          -1
# 29                  0.776955          -1
# 578                 0.811529           1
# 74                  0.764248           1
#
#                                                   SASB  \
# 87   {'Water Management': 'Hotel buildings require ...
# 53   {'Greenhouse Gas Emissions': 'Air Freight & Lo...
# 301  {'Workforce Diversity & Inclusion': 'The Multi...
# 184  {'Product Packaging & Distribution': 'A signif...
# 419  {'Customer Health & Safety': 'Cruise lines off...
# ..                                                 ...
# 521  {'Greenhouse Gas Emissions': 'Landfills are a ...
# 19   {'Tailings Storage Facilities Management': 'Th...
# 29   {'Water Management': 'Water management relates...
# 578  {'Product Safety': 'Driving is a risky activit...
# 74   {'Product Safety': 'Information on product saf...
#
#                                         SASB_embedding dataset  \
# 87   {'Water Management': [0.013346040463976059, -0...   train
# 53   {'Greenhouse Gas Emissions': [0.00950879266272...   train
# 301  {'Workforce Diversity & Inclusion': [-0.022194...   train
# 184  {'Product Packaging & Distribution': [0.017690...   train
# 419  {'Customer Health & Safety': [0.02446571152799...   train
# ..                                                 ...     ...
# 521  {'Greenhouse Gas Emissions': [-0.0001698792302...    test
# 19   {'Tailings Storage Facilities Management': [0....    test
# 29   {'Water Management': [0.007515041336335117, -0...    test
# 578  {'Product Safety': [-0.00859951505673047, -0.0...    test
# 74   {'Product Safety': [0.009879209524762098, -0.0...    test
#
#                                              embedding  \
# 87   [0.0034837801940739155, -0.018379943445324898,...
# 53   [-0.016028370708227158, -0.038418304175138474,...
# 301  [0.006538767833262682, -0.0335729718208313, -0...
# 184  [-0.012135321274399757, -0.015672283247113228,...
# 419  [0.00059090880677104, -0.040115032345056534, 0...
# ..                                                 ...
# 521  [-0.005872064735740423, -0.031545888632535934,...
# 19   [-0.013726205565035343, -0.023092789575457573,...
# 29   [-0.008213700726628304, -0.018072837963700294,...
# 578  [-0.02998894639313221, -0.019518667832016945, ...
# 74   [-0.004129682667553425, -0.011016884818673134,...
#
#                                    cosine_similarities
# 87   {'Water Management': 0.7505384757725996, 'Clim...
# 53   {'Greenhouse Gas Emissions': 0.794454891784717...
# 301  {'Workforce Diversity & Inclusion': 0.76499455...
# 184  {'Product Packaging & Distribution': 0.7775707...
# 419  {'Customer Health & Safety': 0.787090176529222...
# ..                                                 ...
# 521  {'Greenhouse Gas Emissions': 0.743747592175264...
# 19   {'Tailings Storage Facilities Management': 0.7...
# 29   {'Water Management': 0.7251327993457838, 'Prod...
# 578  {'Product Safety': 0.742490300578744, 'Materia...
# 74   {'Product Safety': 0.7320296215845231, 'Supply...
#
# [555 rows x 11 columns]

# %%
print(df['SASB_embedding'].iloc[0])
# Out:
# {'Water Management': [0.013346040463976059, -0.014947034242274502, 0.01824202553272061, -0.00801161015269346, 0.01573092285614651, 0.021244717511281177, -0.009466455206371696, -0.002859865980016756, 0.00016628575198718293, -0.03648405106544122, -0.004809623527419138, 0.02403483138940294, 0.003839726980187406, 0.008762284078656165, -0.005962205980426125, -0.004560506383180152, 0.03308276793080801, -0.0062777543631288395, 0.027024238982915894, -0.012070560685472454, -0.028884313659900317, 0.004723262917416289, -0.01537219416844237, 0.014880603003810772, -0.020354538915867203, -0.008117900134235426, 0.01092129932872737, -0.028166856284492038, -0.005859237560807344, -0.02169644993283454, 0.012661798707799645, -0.017325274441921144, -0.030106648447632937, -0.0031239301529100805, -0.005683194778878461, -0.016740677680795197, 0.005291250006281176, 0.0014606574377978528, 0.007267580281899689, -0.022865641592441303, 0.015491770397677082, 0.007174576548050468, 0.010629001879486961, 0.018228739285027863, -0.02238733667550245, 0.02837943624757597, 0.01946436032045323, 0.012090490057011573, -0.013711413206849134, 0.02270620662012835, 0.003796546675185982, 0.026678794680259372, -0.018906337917357904, -0.004098808810195951, -0.013226464234741346, 0.014455443077642904, -0.007506732740369115, -0.00760637959806471, 0.015199472948436673, -0.03207301310615933, 0.0006360793411208501, -0.0036470763886425907, -0.022732779115513843, -0.007686097084221185, -0.014349153096100936, -0.0027303248321818427, -0.006543479316983757, 0.008516488496340366, 0.035554013726949, -0.018800047935815935, 0.02848572622911794, 0.02265306162935737, -0.006922137841888296, 0.015956789066923188, 0.007712669579606677, -0.02493829623250966, -0.01729870194653565, 0.0059024178658087685, 0.0043346401724034716, 0.014907175499196264, -0.00807804139115719, -0.026147344772549538, -0.03000035846609097, 0.013658268216078151, 0.007892033923458747, 0.00967903516945563, -0.009619247054838275, -0.004215063477507477, -0.0023068256869755678, 0.012721586822417003, -0.0033979592444036053, 0.003110643905217335, -0.012854449299344461, 0.027077383973686874, -0.005699802588494393, 0.004746513850878594, 0.006739451936113041, 0.008310550725780241, 0.011392962053142414, -0.0095395295686818, -0.00799168078115434, 0.02297193157398327, -0.03473026636999876, -0.00302594407617608, -0.03515542629616663, 0.009778682027151226, 0.013465617624533336, -0.012974025528579174, 0.008968220917893727, -0.017285415698842906, -0.04086851280404736, 0.020779698842035073, -0.008662637220960572, -0.008709139087885181, -0.005304536253973921, -0.016581242708482245, 0.013000598023964666, -0.007486803368829996, -0.009028009032511082, 0.021457297474365113, 0.0006190563362645195, -0.0022619846010125504, 0.017577713148083315, -0.0007257615712545451, 0.024300556343257857, 0.0018866478708618383, -0.01917206287121282, 0.005055419109734936, -0.01276144556549524, -0.025097731204822612, -0.003188700610412217, 0.00022814987191036108, 0.008024896400386205, 0.007393799634980776, -0.033375065380048426, 0.010044406981006143, -0.006842420355731821, 0.007971751409615221, 0.007666167712682066, -0.01330618172089782, -0.0004882697773313919, 0.007241007786514197, -0.03682949350545261, -0.008762284078656165, -0.0025376742406370274, 0.02677180027675372, -0.0016051453814564644, -0.006068495961968091, -0.001292088053780819, -0.006364114973131688, -0.0005214853965632567, -0.02159015995129257, -0.0008241628432289443, 0.012043988190086962, -0.0006742773032374945, 0.02970806101685056, -0.011718475121614688, 0.003869621037496084, -0.015438625406906098, -0.019570650301995195, -0.011957627580084115, 0.008662637220960572, -0.0039061582186511352, 0.006061852838121719, 0.012502363735486695, 0.00422170660135385, 0.022613202886279132, 0.019384642834296754, 0.00313389483867964, -0.009386737720215222, -0.001063730671561749, 0.024380273829414333, -0.02258663039089364, 0.006546800878906943, 0.008483271945785938, 0.03475683886538425, -0.003946016961729373, 0.0213377 ...

# %%
def find_max_embedding(sasb_embeddings, cosine_similarities):
    # 找到相似度最高的主题名称
    max_similarity_topic = max(cosine_similarities, key=cosine_similarities.get)
    
    # 提取该主题的embedding
    max_embedding = sasb_embeddings.get(max_similarity_topic, None)
    return max_embedding

# 应用find_max_embedding函数
df['max_embedding'] = df.apply(lambda row: find_max_embedding(row['SASB_embedding'], row['cosine_similarities']), axis=1)
df['max_embedding_word'] = df.apply(lambda row: find_max_embedding(row['SASB'], row['cosine_similarities']), axis=1)

# %%
df
# Out:
#                                                content  \
# 87   More millennials are turning 40 ‚Äî and they'r...
# 53   FedEx Parks Planes, Maersk Cancels Sails: Worl...
# 301  You could be buying shoplifted stuff on Amazon...
# 184  Marketers: Turn Impressions Into Intent This H...
# 419  Royal Caribbean Inks Sustainable Shipbuilding ...
# ..                                                 ...
# 521  Waste Management (WM) Stock Moves -0.91%: What...
# 19   Newmont Corporation (NEM) Stock Moves -0.58%: ...
# 29   CFOs Boost Currency Protections, Extend Hedge ...
# 578  5,000 GM Employees Reportedly Take Buyouts In ...
# 74   Dexcom to build its first European factory in ...
#
#                                              sentiment  \
# 87   {'positive': 0.06741135, 'negative': 0.1715823...
# 53   {'positive': 0.0276921, 'negative': 0.91408736...
# 301  {'positive': 0.034610316, 'negative': 0.476638...
# 184  {'positive': 0.09345539, 'negative': 0.0399913...
# 419  {'positive': 0.30869853, 'negative': 0.0087451...
# ..                                                 ...
# 521  {'positive': 0.6840206, 'negative': 0.23210213...
# 19   {'positive': 0.07588659, 'negative': 0.8466317...
# 29   {'positive': 0.031100325, 'negative': 0.955758...
# 578  {'positive': 0.013290622, 'negative': 0.963200...
# 74   {'positive': 0.8870371, 'negative': 0.06326054...
#
#                                 Sector  \
# 87                            Services
# 53                      Transportation
# 301                     Consumer Goods
# 184                     Consumer Goods
# 419                     Transportation
# ..                                 ...
# 521                     Infrastructure
# 19   Extractives & Minerals Processing
# 29                     Food & Beverage
# 578                     Transportation
# 74                         Health Care
#
#                                              Industry  \
# 87                                   Hotels & Lodging
# 53                            Air Freight & Logistics
# 301  Multiline and Specialty Retailers & Distributors
# 184                                        E-Commerce
# 419                                      Cruise Lines
# ..                                                ...
# 521                                  Waste Management
# 19                                    Metals & Mining
# 29                            Non-Alcoholic Beverages
# 578                                       Automobiles
# 74                       Medical Equipment & Supplies
#
#      max_cosine_similarities  ESG_or_not  \
# 87                  0.785040          -1
# 53                  0.806254          -1
# 301                 0.803166           1
# 184                 0.802793          -1
# 419                 0.792948           1
# ..                       ...         ...
# 521                 0.805994          -1
# 19                  0.756432          -1
# 29                  0.776955          -1
# 578                 0.811529           1
# 74                  0.764248           1
#
#                                                   SASB  \
# 87   {'Water Management': 'Hotel buildings require ...
# 53   {'Greenhouse Gas Emissions': 'Air Freight & Lo...
# 301  {'Workforce Diversity & Inclusion': 'The Multi...
# 184  {'Product Packaging & Distribution': 'A signif...
# 419  {'Customer Health & Safety': 'Cruise lines off...
# ..                                                 ...
# 521  {'Greenhouse Gas Emissions': 'Landfills are a ...
# 19   {'Tailings Storage Facilities Management': 'Th...
# 29   {'Water Management': 'Water management relates...
# 578  {'Product Safety': 'Driving is a risky activit...
# 74   {'Product Safety': 'Information on product saf...
#
#                                         SASB_embedding dataset  \
# 87   {'Water Management': [0.013346040463976059, -0...   train
# 53   {'Greenhouse Gas Emissions': [0.00950879266272...   train
# 301  {'Workforce Diversity & Inclusion': [-0.022194...   train
# 184  {'Product Packaging & Distribution': [0.017690...   train
# 419  {'Customer Health & Safety': [0.02446571152799...   train
# ..                                                 ...     ...
# 521  {'Greenhouse Gas Emissions': [-0.0001698792302...    test
# 19   {'Tailings Storage Facilities Management': [0....    test
# 29   {'Water Management': [0.007515041336335117, -0...    test
# 578  {'Product Safety': [-0.00859951505673047, -0.0...    test
# 74   {'Product Safety': [0.009879209524762098, -0.0...    test
#
#                                              embedding  \
# 87   [0.0034837801940739155, -0.018379943445324898,...
# 53   [-0.016028370708227158, -0.038418304175138474,...
# 301  [0.006538767833262682, -0.0335729718208313, -0...
# 184  [-0.012135321274399757, -0.015672283247113228,...
# 419  [0.00059090880677104, -0.040115032345056534, 0...
# ..                                                 ...
# 521  [-0.005872064735740423, -0.031545888632535934,...
# 19   [-0.013726205565035343, -0.023092789575457573,...
# 29   [-0.008213700726628304, -0.018072837963700294,...
# 578  [-0.02998894639313221, -0.019518667832016945, ...
# 74   [-0.004129682667553425, -0.011016884818673134,...
#
#                                    cosine_similarities  \
# 87   {'Water Management': 0.7505384757725996, 'Clim...
# 53   {'Greenhouse Gas Emissions': 0.794454891784717...
# 301  {'Workforce Diversity & Inclusion': 0.76499455...
# 184  {'Product Packaging & Distribution': 0.7775707...
# 419  {'Customer Health & Safety': 0.787090176529222...
# ..                                                 ...
# 521  {'Greenhouse Gas Emissions': 0.743747592175264...
# 19   {'Tailings Storage Facilities Management': 0.7...
# 29   {'Water Management': 0.7251327993457838, 'Prod...
# 578  {'Product Safety': 0.742490300578744, 'Materia...
# 74   {'Product Safety': 0.7320296215845231, 'Supply...
#
#                                          max_embedding  \
# 87   [0.008788215686639065, -0.005378414729180266, ...
# 53   [-0.002340704698821943, -0.040607881330244414,...
# 301  [-0.006217272626085497, -0.0009317641472651714...
# 184  [0.009207524693889902, -0.012759092727629052, ...
# 419  [0.0242732587449533, -0.027872304145332892, 0....
# ..                                                 ...
# 521  [-0.0011502468158345717, -0.032458606820530075...
# 19   [-0.00513920216254887, -0.02769421873927176, 0...
# 29   [0.016293765295825713, -0.047365905599416926, ...
# 578  [-0.009876224631166941, -0.024663868011668925,...
# 74   [0.00859934072760753, -0.015047205981286865, 0...
#
#                                     max_embedding_word
# 87   The Hotels & Lodging industry is highly relian...
# 53   Employees in the Air Freight & Logistics indus...
# 301  Consumers trust retail entities with their fin...
# 184  The business model of entities in the E-Commer...
# 419  Cruise entities operate a uniquely transitory ...
# ..                                                 ...
# 521  Organised labour plays an important role in th...
# 19   Metals and mining entities face inherent tensi...
# 29   Entities in the Non-Alcoholic Beverages indust...
# 578  Many workers in the Automobiles industry are c...
# 74   Medical equipment and supplies entities are su...
#
# [555 rows x 13 columns]

# %%
df
# Out:
#                                                content  \
# 87   More millennials are turning 40 ‚Äî and they'r...
# 53   FedEx Parks Planes, Maersk Cancels Sails: Worl...
# 301  You could be buying shoplifted stuff on Amazon...
# 184  Marketers: Turn Impressions Into Intent This H...
# 419  Royal Caribbean Inks Sustainable Shipbuilding ...
# ..                                                 ...
# 521  Waste Management (WM) Stock Moves -0.91%: What...
# 19   Newmont Corporation (NEM) Stock Moves -0.58%: ...
# 29   CFOs Boost Currency Protections, Extend Hedge ...
# 578  5,000 GM Employees Reportedly Take Buyouts In ...
# 74   Dexcom to build its first European factory in ...
#
#                                              sentiment  \
# 87   {'positive': 0.06741135, 'negative': 0.1715823...
# 53   {'positive': 0.0276921, 'negative': 0.91408736...
# 301  {'positive': 0.034610316, 'negative': 0.476638...
# 184  {'positive': 0.09345539, 'negative': 0.0399913...
# 419  {'positive': 0.30869853, 'negative': 0.0087451...
# ..                                                 ...
# 521  {'positive': 0.6840206, 'negative': 0.23210213...
# 19   {'positive': 0.07588659, 'negative': 0.8466317...
# 29   {'positive': 0.031100325, 'negative': 0.955758...
# 578  {'positive': 0.013290622, 'negative': 0.963200...
# 74   {'positive': 0.8870371, 'negative': 0.06326054...
#
#                                 Sector  \
# 87                            Services
# 53                      Transportation
# 301                     Consumer Goods
# 184                     Consumer Goods
# 419                     Transportation
# ..                                 ...
# 521                     Infrastructure
# 19   Extractives & Minerals Processing
# 29                     Food & Beverage
# 578                     Transportation
# 74                         Health Care
#
#                                              Industry  \
# 87                                   Hotels & Lodging
# 53                            Air Freight & Logistics
# 301  Multiline and Specialty Retailers & Distributors
# 184                                        E-Commerce
# 419                                      Cruise Lines
# ..                                                ...
# 521                                  Waste Management
# 19                                    Metals & Mining
# 29                            Non-Alcoholic Beverages
# 578                                       Automobiles
# 74                       Medical Equipment & Supplies
#
#      max_cosine_similarities  ESG_or_not  \
# 87                  0.785040          -1
# 53                  0.806254          -1
# 301                 0.803166           1
# 184                 0.802793          -1
# 419                 0.792948           1
# ..                       ...         ...
# 521                 0.805994          -1
# 19                  0.756432          -1
# 29                  0.776955          -1
# 578                 0.811529           1
# 74                  0.764248           1
#
#                                                   SASB  \
# 87   {'Water Management': 'Hotel buildings require ...
# 53   {'Greenhouse Gas Emissions': 'Air Freight & Lo...
# 301  {'Workforce Diversity & Inclusion': 'The Multi...
# 184  {'Product Packaging & Distribution': 'A signif...
# 419  {'Customer Health & Safety': 'Cruise lines off...
# ..                                                 ...
# 521  {'Greenhouse Gas Emissions': 'Landfills are a ...
# 19   {'Tailings Storage Facilities Management': 'Th...
# 29   {'Water Management': 'Water management relates...
# 578  {'Product Safety': 'Driving is a risky activit...
# 74   {'Product Safety': 'Information on product saf...
#
#                                         SASB_embedding dataset  \
# 87   {'Water Management': [0.013346040463976059, -0...   train
# 53   {'Greenhouse Gas Emissions': [0.00950879266272...   train
# 301  {'Workforce Diversity & Inclusion': [-0.022194...   train
# 184  {'Product Packaging & Distribution': [0.017690...   train
# 419  {'Customer Health & Safety': [0.02446571152799...   train
# ..                                                 ...     ...
# 521  {'Greenhouse Gas Emissions': [-0.0001698792302...    test
# 19   {'Tailings Storage Facilities Management': [0....    test
# 29   {'Water Management': [0.007515041336335117, -0...    test
# 578  {'Product Safety': [-0.00859951505673047, -0.0...    test
# 74   {'Product Safety': [0.009879209524762098, -0.0...    test
#
#                                              embedding  \
# 87   [0.0034837801940739155, -0.018379943445324898,...
# 53   [-0.016028370708227158, -0.038418304175138474,...
# 301  [0.006538767833262682, -0.0335729718208313, -0...
# 184  [-0.012135321274399757, -0.015672283247113228,...
# 419  [0.00059090880677104, -0.040115032345056534, 0...
# ..                                                 ...
# 521  [-0.005872064735740423, -0.031545888632535934,...
# 19   [-0.013726205565035343, -0.023092789575457573,...
# 29   [-0.008213700726628304, -0.018072837963700294,...
# 578  [-0.02998894639313221, -0.019518667832016945, ...
# 74   [-0.004129682667553425, -0.011016884818673134,...
#
#                                    cosine_similarities  \
# 87   {'Water Management': 0.7505384757725996, 'Clim...
# 53   {'Greenhouse Gas Emissions': 0.794454891784717...
# 301  {'Workforce Diversity & Inclusion': 0.76499455...
# 184  {'Product Packaging & Distribution': 0.7775707...
# 419  {'Customer Health & Safety': 0.787090176529222...
# ..                                                 ...
# 521  {'Greenhouse Gas Emissions': 0.743747592175264...
# 19   {'Tailings Storage Facilities Management': 0.7...
# 29   {'Water Management': 0.7251327993457838, 'Prod...
# 578  {'Product Safety': 0.742490300578744, 'Materia...
# 74   {'Product Safety': 0.7320296215845231, 'Supply...
#
#                                          max_embedding
# 87   [0.008788215686639065, -0.005378414729180266, ...
# 53   [-0.002340704698821943, -0.040607881330244414,...
# 301  [-0.006217272626085497, -0.0009317641472651714...
# 184  [0.009207524693889902, -0.012759092727629052, ...
# 419  [0.0242732587449533, -0.027872304145332892, 0....
# ..                                                 ...
# 521  [-0.0011502468158345717, -0.032458606820530075...
# 19   [-0.00513920216254887, -0.02769421873927176, 0...
# 29   [0.016293765295825713, -0.047365905599416926, ...
# 578  [-0.009876224631166941, -0.024663868011668925,...
# 74   [0.00859934072760753, -0.015047205981286865, 0...
#
# [555 rows x 12 columns]

# %%
df.to_csv('/Users/ruiqizhou/Downloads/annotation4_after2word.csv', index=False)

# %%
df = pd.read_csv('/Users/ruiqizhou/Downloads/annotation4_after2word.csv')

# %%
df
# Out:
#                                                content  \
# 0    More millennials are turning 40 ‚Äî and they'r...
# 1    FedEx Parks Planes, Maersk Cancels Sails: Worl...
# 2    You could be buying shoplifted stuff on Amazon...
# 3    Marketers: Turn Impressions Into Intent This H...
# 4    Royal Caribbean Inks Sustainable Shipbuilding ...
# ..                                                 ...
# 550  Waste Management (WM) Stock Moves -0.91%: What...
# 551  Newmont Corporation (NEM) Stock Moves -0.58%: ...
# 552  CFOs Boost Currency Protections, Extend Hedge ...
# 553  5,000 GM Employees Reportedly Take Buyouts In ...
# 554  Dexcom to build its first European factory in ...
#
#                                              sentiment  \
# 0    {'positive': 0.06741135, 'negative': 0.1715823...
# 1    {'positive': 0.0276921, 'negative': 0.91408736...
# 2    {'positive': 0.034610316, 'negative': 0.476638...
# 3    {'positive': 0.09345539, 'negative': 0.0399913...
# 4    {'positive': 0.30869853, 'negative': 0.0087451...
# ..                                                 ...
# 550  {'positive': 0.6840206, 'negative': 0.23210213...
# 551  {'positive': 0.07588659, 'negative': 0.8466317...
# 552  {'positive': 0.031100325, 'negative': 0.955758...
# 553  {'positive': 0.013290622, 'negative': 0.963200...
# 554  {'positive': 0.8870371, 'negative': 0.06326054...
#
#                                 Sector  \
# 0                             Services
# 1                       Transportation
# 2                       Consumer Goods
# 3                       Consumer Goods
# 4                       Transportation
# ..                                 ...
# 550                     Infrastructure
# 551  Extractives & Minerals Processing
# 552                    Food & Beverage
# 553                     Transportation
# 554                        Health Care
#
#                                              Industry  \
# 0                                    Hotels & Lodging
# 1                             Air Freight & Logistics
# 2    Multiline and Specialty Retailers & Distributors
# 3                                          E-Commerce
# 4                                        Cruise Lines
# ..                                                ...
# 550                                  Waste Management
# 551                                   Metals & Mining
# 552                           Non-Alcoholic Beverages
# 553                                       Automobiles
# 554                      Medical Equipment & Supplies
#
#      max_cosine_similarities  ESG_or_not  \
# 0                   0.785040          -1
# 1                   0.806254          -1
# 2                   0.803166           1
# 3                   0.802793          -1
# 4                   0.792948           1
# ..                       ...         ...
# 550                 0.805994          -1
# 551                 0.756432          -1
# 552                 0.776955          -1
# 553                 0.811529           1
# 554                 0.764248           1
#
#                                                   SASB  \
# 0    {'Water Management': 'Hotel buildings require ...
# 1    {'Greenhouse Gas Emissions': 'Air Freight & Lo...
# 2    {'Workforce Diversity & Inclusion': 'The Multi...
# 3    {'Product Packaging & Distribution': 'A signif...
# 4    {'Customer Health & Safety': 'Cruise lines off...
# ..                                                 ...
# 550  {'Greenhouse Gas Emissions': 'Landfills are a ...
# 551  {'Tailings Storage Facilities Management': 'Th...
# 552  {'Water Management': 'Water management relates...
# 553  {'Product Safety': 'Driving is a risky activit...
# 554  {'Product Safety': 'Information on product saf...
#
#                                         SASB_embedding dataset  \
# 0    {'Water Management': [0.013346040463976059, -0...   train
# 1    {'Greenhouse Gas Emissions': [0.00950879266272...   train
# 2    {'Workforce Diversity & Inclusion': [-0.022194...   train
# 3    {'Product Packaging & Distribution': [0.017690...   train
# 4    {'Customer Health & Safety': [0.02446571152799...   train
# ..                                                 ...     ...
# 550  {'Greenhouse Gas Emissions': [-0.0001698792302...    test
# 551  {'Tailings Storage Facilities Management': [0....    test
# 552  {'Water Management': [0.007515041336335117, -0...    test
# 553  {'Product Safety': [-0.00859951505673047, -0.0...    test
# 554  {'Product Safety': [0.009879209524762098, -0.0...    test
#
#                                              embedding  \
# 0    [0.0034837801940739155, -0.018379943445324898,...
# 1    [-0.016028370708227158, -0.038418304175138474,...
# 2    [0.006538767833262682, -0.0335729718208313, -0...
# 3    [-0.012135321274399757, -0.015672283247113228,...
# 4    [0.00059090880677104, -0.040115032345056534, 0...
# ..                                                 ...
# 550  [-0.005872064735740423, -0.031545888632535934,...
# 551  [-0.013726205565035343, -0.023092789575457573,...
# 552  [-0.008213700726628304, -0.018072837963700294,...
# 553  [-0.02998894639313221, -0.019518667832016945, ...
# 554  [-0.004129682667553425, -0.011016884818673134,...
#
#                                    cosine_similarities  \
# 0    {'Water Management': 0.7505384757725996, 'Clim...
# 1    {'Greenhouse Gas Emissions': 0.794454891784717...
# 2    {'Workforce Diversity & Inclusion': 0.76499455...
# 3    {'Product Packaging & Distribution': 0.7775707...
# 4    {'Customer Health & Safety': 0.787090176529222...
# ..                                                 ...
# 550  {'Greenhouse Gas Emissions': 0.743747592175264...
# 551  {'Tailings Storage Facilities Management': 0.7...
# 552  {'Water Management': 0.7251327993457838, 'Prod...
# 553  {'Product Safety': 0.742490300578744, 'Materia...
# 554  {'Product Safety': 0.7320296215845231, 'Supply...
#
#                                          max_embedding  \
# 0    [0.008788215686639065, -0.005378414729180266, ...
# 1    [-0.002340704698821943, -0.040607881330244414,...
# 2    [-0.006217272626085497, -0.0009317641472651714...
# 3    [0.009207524693889902, -0.012759092727629052, ...
# 4    [0.0242732587449533, -0.027872304145332892, 0....
# ..                                                 ...
# 550  [-0.0011502468158345717, -0.032458606820530075...
# 551  [-0.00513920216254887, -0.02769421873927176, 0...
# 552  [0.016293765295825713, -0.047365905599416926, ...
# 553  [-0.009876224631166941, -0.024663868011668925,...
# 554  [0.00859934072760753, -0.015047205981286865, 0...
#
#                                     max_embedding_word
# 0    The Hotels & Lodging industry is highly relian...
# 1    Employees in the Air Freight & Logistics indus...
# 2    Consumers trust retail entities with their fin...
# 3    The business model of entities in the E-Commer...
# 4    Cruise entities operate a uniquely transitory ...
# ..                                                 ...
# 550  Organised labour plays an important role in th...
# 551  Metals and mining entities face inherent tensi...
# 552  Entities in the Non-Alcoholic Beverages indust...
# 553  Many workers in the Automobiles industry are c...
# 554  Medical equipment and supplies entities are su...
#
# [555 rows x 13 columns]

# %%
import json
import numpy as np
import pandas as pd

# 假设df是您的DataFrame，'embedding'是需要转换的列
def convert_embedding(embedding_str):
    try:
        # 将字符串解析为数值列表
        embedding_list = json.loads(embedding_str)
        return np.array(embedding_list, dtype=np.float64)
    except json.JSONDecodeError:
        return np.nan  # 或者根据需要返回适当的默认值

# 应用转换函数
df['embedding'] = df['embedding'].apply(convert_embedding)

# %%
df['max_embedding'] = df['max_embedding'].apply(convert_embedding)

# %% [markdown]
# embeddings

# %%
def embedding_multiplied_by_matrix(
    embedding: List[float], matrix: torch.tensor
) -> np.array:
    embedding_tensor = torch.tensor(embedding).float()
    modified_embedding = embedding_tensor @ matrix
    modified_embedding = modified_embedding.detach().numpy()
    return modified_embedding


# compute custom embeddings and new cosine similarities
def apply_matrix_to_embeddings_dataframe(matrix: torch.tensor, df: pd.DataFrame):
    for column in ["embedding", "max_embedding"]:
        df[f"{column}_custom"] = df[column].apply(
            lambda x: embedding_multiplied_by_matrix(x, matrix)
        )
    df["cosine_similarity_custom"] = df.apply(
        lambda row: cosine_similarity(
            row["embedding_custom"], row["max_embedding_custom"]
        ),
        axis=1,
    )

# %%
def optimize_matrix(
    modified_embedding_length: int = 2048,  # in my brief experimentation, bigger was better (2048 is length of babbage encoding)
    batch_size: int = 100,
    max_epochs: int = 100,
    learning_rate: float = 100.0,  # seemed to work best when similar to batch size - feel free to try a range of values
    dropout_fraction: float = 0.0,  # in my testing, dropout helped by a couple percentage points (definitely not necessary)
    df: pd.DataFrame = df,
    print_progress: bool = True,
    save_results: bool = True,
) -> torch.tensor:
    """Return matrix optimized to minimize loss on training data."""
    run_id = random.randint(0, 2 ** 31 - 1)  # (range is arbitrary)
    # convert from dataframe to torch tensors
    # e is for embedding, s for similarity label
    def tensors_from_dataframe(
        df: pd.DataFrame,
        embedding_column_1: str,
        embedding_column_2: str,
        similarity_label_column: str,
    ) -> Tuple[torch.tensor]:
        e1 = np.stack(np.array(df[embedding_column_1].values))
        e2 = np.stack(np.array(df[embedding_column_2].values))
        s = np.stack(np.array(df[similarity_label_column].astype("float").values))

        e1 = torch.from_numpy(e1).float()
        e2 = torch.from_numpy(e2).float()
        s = torch.from_numpy(s).float()

        return e1, e2, s

    e1_train, e2_train, s_train = tensors_from_dataframe(
        df[df["dataset"] == "train"], "embedding", "max_embedding", "ESG_or_not"
    )
    e1_test, e2_test, s_test = tensors_from_dataframe(
        df[df["dataset"] == "test"], "embedding", "max_embedding", "ESG_or_not"
    )

    # create dataset and loader
    dataset = torch.utils.data.TensorDataset(e1_train, e2_train, s_train)
    train_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=True
    )

    # define model (similarity of projected embeddings)
    def model(embedding_1, embedding_2, matrix, dropout_fraction=dropout_fraction):
        e1 = torch.nn.functional.dropout(embedding_1, p=dropout_fraction)
        e2 = torch.nn.functional.dropout(embedding_2, p=dropout_fraction)
        modified_embedding_1 = e1 @ matrix  # @ is matrix multiplication
        modified_embedding_2 = e2 @ matrix
        similarity = torch.nn.functional.cosine_similarity(
            modified_embedding_1, modified_embedding_2
        )
        return similarity

    # define loss function to minimize
    def mse_loss(predictions, targets):
        difference = predictions - targets
        return torch.sum(difference * difference) / difference.numel()

    # initialize projection matrix
    embedding_length = len(df["embedding"].values[0])
    matrix = torch.randn(
        embedding_length, modified_embedding_length, requires_grad=True
    )

    epochs, types, losses, accuracies, matrices = [], [], [], [], []
    for epoch in range(1, 1 + max_epochs):
        # iterate through training dataloader
        for a, b, actual_similarity in train_loader:
            # generate prediction
            predicted_similarity = model(a, b, matrix)
            # get loss and perform backpropagation
            loss = mse_loss(predicted_similarity, actual_similarity)
            loss.backward()
            # update the weights
            with torch.no_grad():
                matrix -= matrix.grad * learning_rate
                # set gradients to zero
                matrix.grad.zero_()
        # calculate test loss
        test_predictions = model(e1_test, e2_test, matrix)
        test_loss = mse_loss(test_predictions, s_test)

        # compute custom embeddings and new cosine similarities
        apply_matrix_to_embeddings_dataframe(matrix, df)

        # calculate test accuracy
        for dataset in ["train", "test"]:
            data = df[df["dataset"] == dataset]
            a, se = accuracy_and_se(data["max_cosine_similarities"], data["ESG_or_not"])

            # record results of each epoch
            epochs.append(epoch)
            types.append(dataset)
            losses.append(loss.item() if dataset == "train" else test_loss.item())
            accuracies.append(a)
            matrices.append(matrix.detach().numpy())

            # optionally print accuracies
            if print_progress is True:
                print(
                    f"Epoch {epoch}/{max_epochs}: {dataset} accuracy: {a:0.1%} ± {1.96 * se:0.1%}"
                )

    data = pd.DataFrame(
        {"epoch": epochs, "type": types, "loss": losses, "accuracy": accuracies}
    )
    data["run_id"] = run_id
    data["modified_embedding_length"] = modified_embedding_length
    data["batch_size"] = batch_size
    data["max_epochs"] = max_epochs
    data["learning_rate"] = learning_rate
    data["dropout_fraction"] = dropout_fraction
    data[
        "matrix"
    ] = matrices  # saving every single matrix can get big; feel free to delete/change
    if save_results is True:
        data.to_csv(f"{run_id}_optimization_results.csv", index=False)

    return data

# %%
# example hyperparameter search
# I recommend starting with max_epochs=10 while initially exploring
results = []
max_epochs = 30
dropout_fraction = 0.2
for batch_size, learning_rate in [(10, 10), (100, 100), (1000, 1000)]:
    result = optimize_matrix(
        batch_size=batch_size,
        learning_rate=learning_rate,
        max_epochs=max_epochs,
        dropout_fraction=dropout_fraction,
        save_results=False,
    )
    results.append(result)
